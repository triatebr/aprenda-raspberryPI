# %% [markdown]
# #Script para acesso e manipulação de dados do <b>SIGA_DESENV.SRC_PRICING_MERCADOEDU</b>

# %%
import pandas as pd
import cx_Oracle

# %% [markdown]
# Dados de <b>CONEXÃO</b>

# %%
CONNECT_TO_ORACLE = True
con_oracle = CONNECT_TO_ORACLE

if con_oracle:
    try:
        import cx_Oracle
        import pandas as pd

        ip = '172.16.137.63'
        port = '1521'
        service_name = 'aesabi'
        dsn_tns = cx_Oracle.makedsn(ip, port, service_name=service_name)
        connection = cx_Oracle.connect('bi_read', 'bi_read', dsn_tns, encoding="UTF-8", nencoding="UTF-8")

    except:
        connection = None
        print("Oracle AESA BI db connection could not be created")
else:
    connection = None

def read_origin_to_pandas(sql="", path="", sep=',', encoding='utf-8', dtype={}, connection=connection):
    if (con_oracle) or (con_oracle=="True"):
        return pd.read_sql(sql, con=connection)
    else:
        return print('Erro') ##uploads_to_panda(path, sep=sep, encoding=encoding, dtype=dtype)

# %% [markdown]
# <b>SCRIPT</b>

# %%
sql_teste = "select * from SIGA_DESENV.SRC_PRICING_MERCADOEDU WHERE DT_DATE >=TO_DATE('01/02/2019','dd/mm/yyyy')"

# %%
sql_teste
# Out:
# "select * from SIGA_DESENV.SRC_PRICING_MERCADOEDU WHERE DT_DATE >=TO_DATE('01/02/2019','dd/mm/yyyy')"

# %%
TGT_BI_DF = read_origin_to_pandas(sql = sql_teste, path="TESTE", sep=',',dtype={'ID': object})
TGT_BI_DF.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#          ...        DS_COURSE_SHIFT DS_QT_CREDITS NR_PRICE NR_PRICE_W_D  \
# 0        ...                   None          None   461.11        415.0
# 1        ...                   None          None   461.11        415.0
# 2        ...                   None          None   461.11        415.0
# 3        ...                   None          None   461.11        415.0
# 4        ...                   None          None   461.11        415.0
#
#   NR_MATRICULATION NR_MATRICULATION_W_D  DS_EXECUTION_ID             DT_INSR  \
# 0              NaN                  NaN             6225 2019-02-04 08:45:49
# 1              NaN                  NaN             6225 2019-02-04 08:45:49
# 2              NaN                  NaN             6225 2019-02-04 08:45:49
# 3              NaN                  NaN             6225 2019-02-04 08:45:49
# 4              NaN                  NaN             6225 2019-02-04 08:45:49
#
#    DS_ROBO_NAME  DS_LOCAL_ADDRESS
# 0    CLARETIANO              None
# 1    CLARETIANO              None
# 2    CLARETIANO              None
# 3    CLARETIANO              None
# 4    CLARETIANO              None
#
# [5 rows x 24 columns]

# %%
df = pd.DataFrame(TGT_BI_DF)
df.head(3)
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
#
#          ...        DS_COURSE_SHIFT DS_QT_CREDITS NR_PRICE NR_PRICE_W_D  \
# 0        ...                   None          None   461.11        415.0
# 1        ...                   None          None   461.11        415.0
# 2        ...                   None          None   461.11        415.0
#
#   NR_MATRICULATION NR_MATRICULATION_W_D  DS_EXECUTION_ID             DT_INSR  \
# 0              NaN                  NaN             6225 2019-02-04 08:45:49
# 1              NaN                  NaN             6225 2019-02-04 08:45:49
# 2              NaN                  NaN             6225 2019-02-04 08:45:49
#
#    DS_ROBO_NAME  DS_LOCAL_ADDRESS
# 0    CLARETIANO              None
# 1    CLARETIANO              None
# 2    CLARETIANO              None
#
# [3 rows x 24 columns]

# %%
def trata_local_name(row):
    if (row['DS_LOCAL_NAME'])=='-':
        val is None
    else:
        val = row['DS_LOCAL_NAME']
    return val

# %%
df['DS_LOCAL_NAME_DF'] = df.apply(trata_local_name, axis = 1)

# %%
df['DS_LOCAL_ADDRESS_DF'] = df['DS_LOCAL_ADDRESS'].astype(str)
df['DS_COUSER_NAME_DF'] = df['DS_COUSER_NAME'].str.upper()
df['DS_COURSE_DEGREE_DF'] = df['DS_COURSE_DEGREE'].str.upper()
df['DS_COURSE_MODALITY_DF'] = df['DS_COURSE_MODALITY'].str.upper()

# %%
def trata_course_shift(row):
    if (row['DS_COURSE_SHIFT'])=='-':
        val is None
    else:
        val = row['DS_COURSE_SHIFT']
    return val

# %%
df['DS_COURSE_SHIFT_DF'] = df.apply(trata_course_shift, axis = 1)

# %%
df['DS_IES_SIGLE_DF'] = df['DS_IES_SIGLE'].str.upper()
df['DS_CITY_NAME_DF'] = df['DS_CITY_NAME'].str.upper()
df['DS_STATE_NAME_DF'] = df['DS_STATE_NAME'].str.upper()
df['DS_PAYMENT_PLAN_DF'] = df['DS_PAYMENT_PLAN'].str.upper()
df['DS_QT_CREDITS_DF'] = df['DS_QT_CREDITS'].str.upper()
df['DS_ROBO_NAME_DF'] = df['DS_ROBO_NAME'].str.upper()
df['ROBO_ORIG_DF'] = df['DS_ROBO_NAME'].str.upper()
df['ENDERECO_LOCAL_DF'] = df['DS_LOCAL_ADDRESS_DF'].astype(str)
import time
df['DT_BASE_DF'] = time.strftime("%d/%m/%Y")

# %%
def trata_robo_tratado(row):
    if (row['DS_ROBO_NAME'])=='EDUCAMAIS BRASIL':
        val = 'EDUCA MAIS'
    elif (row['DS_ROBO_NAME'])=='QUERO BOLSA':
        val = 'QUERO BOLSA'
    else:
        val = 'SITE'
    return val

# %%
df['ROBO_TRATADO_DF'] = df.apply(trata_robo_tratado, axis = 1)

# %% [markdown]
# Dados de <b>'NR_PRICE'</b> e <b>'NR_PRICE_W_D'</b> convertidos para String, <p>para o cálculo das info's sobre <b>'NR_PRICE_TRATADO'</b> e <b>'NR_PRICE_W_D_TRATADO'</b>

# %%
df['NR_PRICE_STR'] = df['NR_PRICE'].apply(lambda x: str(x))

# %%
df['NR_PRICE_LN'] = df["NR_PRICE_STR"].apply(lambda x: len(str(x)))

# %%
def trata_price(row):
    if(row['NR_PRICE_LN']==5):
        val = row['NR_PRICE_STR']
    elif row['NR_PRICE_LN']==6:
        val = row['NR_PRICE_STR']
    else:
        val = row['NR_PRICE_STR']
    return val

# %%
df['NR_PRICE_TRATADO_DF'] = df.apply(trata_price, axis = 1)

# %%
df['NR_PRICE_WD_STR'] = df['NR_PRICE_W_D'].apply(lambda x: str(x))

# %%
df['NR_PRICE_WD_LN'] = df["NR_PRICE_WD_STR"].apply(lambda x: len(str(x)))

# %%
def trata_price_wd(row):
    if(row['NR_PRICE_WD_LN']==5):
        val = row['NR_PRICE_WD_STR']
    elif row['NR_PRICE_WD_LN']==6:
        val = row['NR_PRICE_WD_STR']
    else:
        val = row['NR_PRICE_WD_STR']
    return val

# %%
df['NR_PRICE_W_D_TRATADO_DF'] = df.apply(trata_price, axis = 1)

# %%
def trata_preco(row):
    if(row['NR_PRICE_LN']==0):
        val = row['NR_PRICE_W_D_TRATADO_DF']
    else:
        val = row['NR_PRICE_TRATADO_DF']
    return val

# %%
df['PRECO_DF']= df.apply(trata_preco, axis = 1)

# %%
def trata_preco_desc(row):
    if(row['NR_PRICE_WD_LN']==0):
        val = row['NR_PRICE_TRATADO_DF']
    else:
        val = row['NR_PRICE_W_D_TRATADO_DF']
    return val

# %%
df['PRECO_DESCONTO_DF']= df.apply(trata_preco_desc, axis = 1)

# %%
def trata_credits(row):
    if(row['DS_QT_CREDITS']!=None):
        val = row['DS_QT_CREDITS']

# %%
df['QTD_CREDITOS_DF']= df.apply(trata_credits, axis = 1)

# %% [markdown]
# Merge para a geração do CAMPO <b>'Plano_Pagamento'</b>

# %%
pgto = pd.read_excel('DePara_Plano_Pagto.xlsx')
pgto.head()
# Out:
#           ROBO                                     DE_Plano_Pagto  \
# 0  CESUMAR EAD  *Valor com 10% de desconto de pontualidade. Su...
# 1  CESUMAR EAD  *Valor com 25% referente a campanha chegamos m...
# 2  UNICHRISTUS                                             C/H:40
# 3  UNICHRISTUS                                             C/H:80
# 4  UNICHRISTUS                                            C/H:120
#
#                                PARA_Plano_Pagto
# 0                         Desconto Pontualidade
# 1  Campanha Chegamos mais Desconto Pontualidade
# 2                              Carga horária 40
# 3                              Carga horária 80
# 4                             Carga horária 120

# %%
pgto['ROBO'] = pgto['ROBO'].str.upper()
pgto['DE_Plano_Pagto'] = pgto['DE_Plano_Pagto'].str.upper()
pgto['PARA_Plano_Pagto'] = pgto['PARA_Plano_Pagto'].str.upper()

# %%
#criação do campo concatenado
pgto['chave_pgto'] = pgto[['ROBO', 'DE_Plano_Pagto']].apply(lambda x: ''.join(str(x)), axis=1)

# %%
# reordenar dataframe
pgto = pgto[['ROBO','DE_Plano_Pagto','chave_pgto','PARA_Plano_Pagto']]

# %%
#campo concatenado no df
df['chave_pgto'] = df['DS_ROBO_NAME'].fillna('')+df['DS_PAYMENT_PLAN'].fillna('')
df.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#       ...     NR_PRICE_STR NR_PRICE_LN NR_PRICE_TRATADO_DF NR_PRICE_WD_STR  \
# 0     ...           461.11           6              461.11           415.0
# 1     ...           461.11           6              461.11           415.0
# 2     ...           461.11           6              461.11           415.0
# 3     ...           461.11           6              461.11           415.0
# 4     ...           461.11           6              461.11           415.0
#
#   NR_PRICE_WD_LN NR_PRICE_W_D_TRATADO_DF  PRECO_DF  PRECO_DESCONTO_DF  \
# 0              5                  461.11    461.11             461.11
# 1              5                  461.11    461.11             461.11
# 2              5                  461.11    461.11             461.11
# 3              5                  461.11    461.11             461.11
# 4              5                  461.11    461.11             461.11
#
#    QTD_CREDITOS_DF  chave_pgto
# 0             None  CLARETIANO
# 1             None  CLARETIANO
# 2             None  CLARETIANO
# 3             None  CLARETIANO
# 4             None  CLARETIANO
#
# [5 rows x 50 columns]

# %%
rs=pd.merge(df, pgto[['chave_pgto','PARA_Plano_Pagto']], on='chave_pgto', how='left')
rs["PARA_Plano_Pagto"].fillna("NI", inplace = True) 
rs.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#          ...        NR_PRICE_LN NR_PRICE_TRATADO_DF NR_PRICE_WD_STR  \
# 0        ...                  6              461.11           415.0
# 1        ...                  6              461.11           415.0
# 2        ...                  6              461.11           415.0
# 3        ...                  6              461.11           415.0
# 4        ...                  6              461.11           415.0
#
#   NR_PRICE_WD_LN NR_PRICE_W_D_TRATADO_DF PRECO_DF  PRECO_DESCONTO_DF  \
# 0              5                  461.11   461.11             461.11
# 1              5                  461.11   461.11             461.11
# 2              5                  461.11   461.11             461.11
# 3              5                  461.11   461.11             461.11
# 4              5                  461.11   461.11             461.11
#
#    QTD_CREDITOS_DF  chave_pgto  PARA_Plano_Pagto
# 0             None  CLARETIANO                NI
# 1             None  CLARETIANO                NI
# 2             None  CLARETIANO                NI
# 3             None  CLARETIANO                NI
# 4             None  CLARETIANO                NI
#
# [5 rows x 51 columns]

# %%
rs.rename(index=str, columns={"PARA_Plano_Pagto": "PLANO_PAGAMENTO_DF"})
rs.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#          ...        NR_PRICE_LN NR_PRICE_TRATADO_DF NR_PRICE_WD_STR  \
# 0        ...                  6              461.11           415.0
# 1        ...                  6              461.11           415.0
# 2        ...                  6              461.11           415.0
# 3        ...                  6              461.11           415.0
# 4        ...                  6              461.11           415.0
#
#   NR_PRICE_WD_LN NR_PRICE_W_D_TRATADO_DF PRECO_DF  PRECO_DESCONTO_DF  \
# 0              5                  461.11   461.11             461.11
# 1              5                  461.11   461.11             461.11
# 2              5                  461.11   461.11             461.11
# 3              5                  461.11   461.11             461.11
# 4              5                  461.11   461.11             461.11
#
#    QTD_CREDITOS_DF  chave_pgto  PARA_Plano_Pagto
# 0             None  CLARETIANO                NI
# 1             None  CLARETIANO                NI
# 2             None  CLARETIANO                NI
# 3             None  CLARETIANO                NI
# 4             None  CLARETIANO                NI
#
# [5 rows x 51 columns]

# %% [markdown]
# Merge para geração do CAMPO <b>'CIDADE_UF'</b>

# %%
cid = pd.read_excel('DePara_Robo_Preços_Novo.xlsx', sheetname='Local_Marca_Grupo_Cidade_Grau')
cid.head()
# Out:
# C:\Users\Lucas Barros\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#           ROBÔ    SIGLA_IES_DE   CIDADE_DE             UF_DE    NOME_LOCAL_DE  \
# 0    AIEC-FAAB            AIEC         NaN  DISTRITO FEDERAL              NaN
# 1    AIEC-FAAB             NaN         NaN               NaN              NaN
# 2  CESUMAR EAD  UNICESUMAR EAD  ABAETETUBA                PA       ABAETETUBA
# 3  CESUMAR EAD      UNICESUMAR  ABAETETUBA                PA  ABAETETUBA - PA
# 4  CESUMAR EAD  UNICESUMAR EAD  AÇAILÆNDIA                MA       AÇAILÆNDIA
#
#   NOME_LOCAL_PARA   MARCA_PARA   GRUPO_PARA    CIDADE_PARA UF_PARA
# 0             NaN  AIEC / FAAB  AIEC / FAAB    BRASILIA/DF      DF
# 1             NaN  AIEC / FAAB  AIEC / FAAB    BRASILIA/DF      DF
# 2      ABAETETUBA      CESUMAR      CESUMAR  ABAETETUBA/PA      PA
# 3      ABAETETUBA      CESUMAR      CESUMAR  ABAETETUBA/PA      PA
# 4   ACAILANDIA/MA      CESUMAR      CESUMAR  ACAILANDIA/MA      MA

# %%
cid['ROBO'] = cid['ROBÔ'].str.upper()
cid['SIGLA_IES_DE'] = cid['SIGLA_IES_DE'].str.upper()
cid['CIDADE_DE'] = cid['CIDADE_DE'].str.upper()
cid['UF_DE'] = cid['UF_DE'].str.upper()
cid['NOME_LOCAL_DE'] = cid['NOME_LOCAL_DE'].str.upper()
cid['NOME_LOCAL_PARA'] = cid['NOME_LOCAL_PARA'].str.upper()
cid['MARCA_PARA'] = cid['MARCA_PARA'].str.upper()
cid['GRUPO_PARA'] = cid['GRUPO_PARA'].str.upper()
cid['CIDADE_PARA'] = cid['CIDADE_PARA'].str.upper()
cid['UF_PARA'] = cid['UF_PARA'].str.upper()

# %%
# upper(DS_ROBO_NAME) &'|'& upper(DS_IES_SIGLE)  &'|'& upper(DS_CITY_NAME) &'|'& upper(DS_STATE_NAME) &'|'& upper(DS_LOCAL_NAME)

# %%
cid['chave_cuf'] = cid['ROBO'].fillna('')+cid['SIGLA_IES_DE'].fillna('')+cid['CIDADE_DE'].fillna('')+cid['UF_DE'].fillna('')+cid['NOME_LOCAL_DE'].fillna('')
cid.head()
# Out:
#           ROBÔ    SIGLA_IES_DE   CIDADE_DE             UF_DE    NOME_LOCAL_DE  \
# 0    AIEC-FAAB            AIEC         NaN  DISTRITO FEDERAL              NaN
# 1    AIEC-FAAB             NaN         NaN               NaN              NaN
# 2  CESUMAR EAD  UNICESUMAR EAD  ABAETETUBA                PA       ABAETETUBA
# 3  CESUMAR EAD      UNICESUMAR  ABAETETUBA                PA  ABAETETUBA - PA
# 4  CESUMAR EAD  UNICESUMAR EAD  AÇAILÆNDIA                MA       AÇAILÆNDIA
#
#   NOME_LOCAL_PARA   MARCA_PARA   GRUPO_PARA    CIDADE_PARA UF_PARA  \
# 0             NaN  AIEC / FAAB  AIEC / FAAB    BRASILIA/DF      DF
# 1             NaN  AIEC / FAAB  AIEC / FAAB    BRASILIA/DF      DF
# 2      ABAETETUBA      CESUMAR      CESUMAR  ABAETETUBA/PA      PA
# 3      ABAETETUBA      CESUMAR      CESUMAR  ABAETETUBA/PA      PA
# 4   ACAILANDIA/MA      CESUMAR      CESUMAR  ACAILANDIA/MA      MA
#
#           ROBO                                         chave_cuf
# 0    AIEC-FAAB                     AIEC-FAABAIECDISTRITO FEDERAL
# 1    AIEC-FAAB                                         AIEC-FAAB
# 2  CESUMAR EAD   CESUMAR EADUNICESUMAR EADABAETETUBAPAABAETETUBA
# 3  CESUMAR EAD  CESUMAR EADUNICESUMARABAETETUBAPAABAETETUBA - PA
# 4  CESUMAR EAD   CESUMAR EADUNICESUMAR EADAÇAILÆNDIAMAAÇAILÆNDIA

# %%
#cid.set_index('month')

# %%
# reordenar dataframe
cid = cid[['ROBO','SIGLA_IES_DE','CIDADE_DE','UF_DE','NOME_LOCAL_DE','chave_cuf','NOME_LOCAL_PARA','MARCA_PARA','GRUPO_PARA','CIDADE_PARA','UF_PARA']]

# %%
# upper(DS_ROBO_NAME) &'|'& upper(DS_IES_SIGLE)  &'|'& upper(DS_CITY_NAME) &'|'& upper(DS_STATE_NAME) &'|'& upper(DS_LOCAL_NAME)
rs['chave_cuf'] = rs['DS_ROBO_NAME'].fillna('')+rs['DS_IES_SIGLE'].fillna('')+rs['DS_CITY_NAME'].fillna('')+rs['DS_STATE_NAME'].fillna('')+rs['DS_LOCAL_NAME'].fillna('')

# %%
#rst=pd.merge(rs, cid, on='chave_cuf', how='left')
rft=pd.merge(rs, cid[['chave_cuf','CIDADE_PARA','NOME_LOCAL_PARA','GRUPO_PARA','MARCA_PARA']], on='chave_cuf', how='left')
rft.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#       ...     PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0     ...       461.11            461.11            None  CLARETIANO
# 1     ...       461.11            461.11            None  CLARETIANO
# 2     ...       461.11            461.11            None  CLARETIANO
# 3     ...       461.11            461.11            None  CLARETIANO
# 4     ...       461.11            461.11            None  CLARETIANO
#
#   PARA_Plano_Pagto                                          chave_cuf  \
# 0               NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1               NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2               NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3               NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4               NI              CLARETIANOCLARETIANOSantos  SPSantos
#
#    CIDADE_PARA  NOME_LOCAL_PARA  GRUPO_PARA  MARCA_PARA
# 0          NaN              NaN         NaN         NaN
# 1          NaN              NaN         NaN         NaN
# 2          NaN              NaN         NaN         NaN
# 3          NaN              NaN         NaN         NaN
# 4          NaN              NaN         NaN         NaN
#
# [5 rows x 56 columns]

# %%
rft["CIDADE_PARA"].fillna("NI", inplace = True)
rft.rename(index=str, columns={"CIDADE_PARA": "CIDADE_UF_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 701711  19943850 2019-02-04       UNIBTA         None
# 701712  19943851 2019-02-04       UNIBTA         None
# 701713  19943852 2019-02-04       UNIBTA         None
# 701714  19943853 2019-02-04       UNIBTA         None
# 701715  19943854 2019-02-04       UNIBTA         None
# 701716  19943855 2019-02-04       UNIBTA         None
# 701717  19943856 2019-02-04       UNIBTA         None
# 701718  19943857 2019-02-04       UNIBTA         None
# 701719  19943858 2019-02-04       UNIBTA         None
# 701720  19943859 2019-02-04       UNIBTA         None
# 701721  19943860 2019-02-04       UNIBTA         None
# 701722  19943861 2019-02-04       UNIBTA         None
# 701723  19943862 2019-02-04       UNIBTA         None
# 701724  19943863 2019-02-04       UNIBTA         None
# 701725  19943864 2019-02-04       UNIBTA         None
# 701726  19943865 2019-02-04       UNIBTA         None
# 701727  19943866 2019-02-04       UNIBTA         None
# 701728  19943867 2019-02-04       UNIBTA         None
# 701729  19943868 2019-02-04       UNIBTA         None
# 701730  19943869 2019-02-04       UNIBTA         None
# 701731  19943870 2019-02-04       UNIBTA         None
# 701732  19943871 2019-02-04       UNIBTA         None
# 701733  19943872 2019-02-04       UNIBTA         None
# 701734  19943873 2019-02-04       UNIBTA         None
# 701735  19943874 2019-02-04       UNIBTA         None
# 701736  19943875 2019-02-04       UNIBTA         None
# 701737  19943876 2019-02-04       UNIBTA         None
# 701738  19943877 2019-02-04       UNIBTA         None
# 701739  19943878 2019-02-04       UNIBTA         None
# 701740  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 701711           Tecnólogo em Marketing Digital                EAD
# 701712           Tecnólogo em Segurança Pública                EAD
# 701713      Tecnólogo em Sistemas para Internet                EAD
# 701714                            Administração                EAD
# 701715                       Ciências Contábeis                EAD
# 701716                          Educação Física                EAD
# 701717              Letras - Português e Inglês                EAD
# 701718                                Pedagogia                EAD
# 701719            Tecnólogo em Gestão Comercial                EAD
# 701720  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701721           Tecnólogo em Gestão Financeira                EAD
# 701722              Tecnólogo em Gestão Pública                EAD
# 701723           Tecnólogo em Marketing Digital                EAD
# 701724           Tecnólogo em Segurança Pública                EAD
# 701725      Tecnólogo em Sistemas para Internet                EAD
# 701726                            Administração                EAD
# 701727                       Ciências Contábeis                EAD
# 701728                          Educação Física                EAD
# 701729              Letras - Português e Inglês                EAD
# 701730                                Pedagogia                EAD
# 701731            Tecnólogo em Gestão Comercial                EAD
# 701732  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701733           Tecnólogo em Gestão Financeira                EAD
# 701734              Tecnólogo em Gestão Pública                EAD
# 701735           Tecnólogo em Marketing Digital                EAD
# 701736           Tecnólogo em Segurança Pública                EAD
# 701737      Tecnólogo em Sistemas para Internet                EAD
# 701738                            Administração                EAD
# 701739                       Ciências Contábeis                EAD
# 701740                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID     ...      \
# 0             Tecnólogo          BA            BA       None     ...
# 1             Tecnólogo          RS            RS       None     ...
# 2             Tecnólogo          PA            PA       None     ...
# 3             Tecnólogo          SP            SP       None     ...
# 4             Tecnólogo          SP            SP       None     ...
# 5             Tecnólogo          SP            SP       None     ...
# 6             Tecnólogo          RO            RO       None     ...
# 7             Tecnólogo          SP            SP       None     ...
# 8             Tecnólogo          SP            SP       None     ...
# 9             Tecnólogo          MA            MA       None     ...
# 10            Tecnólogo          RO            RO       None     ...
# 11            Tecnólogo          SP            SP       None     ...
# 12            Tecnólogo          SP            SP       None     ...
# 13            Tecnólogo          SP            SP       None     ...
# 14            Tecnólogo          PE            PE       None     ...
# 15            Tecnólogo          MT            MT       None     ...
# 16            Tecnólogo          CE            CE       None     ...
# 17            Tecnólogo          SP            SP       None     ...
# 18            Tecnólogo          AM            AM       None     ...
# 19            Tecnólogo          DF            DF       None     ...
# 20            Tecnólogo          DF            DF       None     ...
# 21            Tecnólogo          PI            PI       None     ...
# 22            Tecnólogo          MG            MG       None     ...
# 23            Tecnólogo          MG            MG       None     ...
# 24            Tecnólogo          RO            RO       None     ...
# 25            Tecnólogo          ES            ES       None     ...
# 26            Tecnólogo          BA            BA       None     ...
# 27            Tecnólogo          RJ            RJ       None     ...
# 28            Tecnólogo          GO            GO       None     ...
# 29            Tecnólogo          SE            SE       None     ...
# ...                 ...         ...           ...        ...     ...
# 701711             None        None            CE       None     ...
# 701712             None        None            CE       None     ...
# 701713             None        None            CE       None     ...
# 701714             None        None            CE       None     ...
# 701715             None        None            CE       None     ...
# 701716             None        None            CE       None     ...
# 701717             None        None            CE       None     ...
# 701718             None        None            CE       None     ...
# 701719             None        None            CE       None     ...
# 701720             None        None            CE       None     ...
# 701721             None        None            CE       None     ...
# 701722             None        None            CE       None     ...
# 701723             None        None            CE       None     ...
# 701724             None        None            CE       None     ...
# 701725             None        None            CE       None     ...
# 701726             None        None            CE       None     ...
# 701727             None        None            CE       None     ...
# 701728             None        None            CE       None     ...
# 701729             None        None            CE       None     ...
# 701730             None        None            CE       None     ...
# 701731             None        None            CE       None     ...
# 701732             None        None            CE       None     ...
# 701733             None        None            CE       None     ...
# 701734             None        None            CE       None     ...
# 701735             None        None            CE       None     ...
# 701736             None        None            CE       None     ...
# 701737             None        None            CE       None     ...
# 701738             None        None            CE       None     ...
# 701739             None        None            CE       None     ...
# 701740             None        None            CE       None     ...
#
#        PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0        461.11            461.11            None  CLARETIANO
# 1        461.11            461.11            None  CLARETIANO
# 2        461.11            461.11            None  CLARETIANO
# 3        461.11            461.11            None  CLARETIANO
# 4        461.11            461.11            None  CLARETIANO
# 5        461.11            461.11            None  CLARETIANO
# 6        461.11            461.11            None  CLARETIANO
# 7        461.11            461.11            None  CLARETIANO
# 8        461.11            461.11            None  CLARETIANO
# 9        461.11            461.11            None  CLARETIANO
# 10       461.11            461.11            None  CLARETIANO
# 11       461.11            461.11            None  CLARETIANO
# 12       461.11            461.11            None  CLARETIANO
# 13       482.22            482.22            None  CLARETIANO
# 14       461.11            461.11            None  CLARETIANO
# 15       461.11            461.11            None  CLARETIANO
# 16       461.11            461.11            None  CLARETIANO
# 17       461.11            461.11            None  CLARETIANO
# 18       461.11            461.11            None  CLARETIANO
# 19       461.11            461.11            None  CLARETIANO
# 20       482.22            482.22            None  CLARETIANO
# 21       461.11            461.11            None  CLARETIANO
# 22       461.11            461.11            None  CLARETIANO
# 23       461.11            461.11            None  CLARETIANO
# 24       461.11            461.11            None  CLARETIANO
# 25       461.11            461.11            None  CLARETIANO
# 26       461.11            461.11            None  CLARETIANO
# 27       461.11            461.11            None  CLARETIANO
# 28       277.78            277.78            None  CLARETIANO
# 29       277.78            277.78            None  CLARETIANO
# ...         ...               ...             ...         ...
# 701711    261.0             261.0            None      UNIBTA
# 701712    261.0             261.0            None      UNIBTA
# 701713    261.0             261.0            None      UNIBTA
# 701714    303.0             303.0            None      UNIBTA
# 701715    303.0             303.0            None      UNIBTA
# 701716    303.0             303.0            None      UNIBTA
# 701717    303.0             303.0            None      UNIBTA
# 701718    271.0             271.0            None      UNIBTA
# 701719    159.0             159.0            None      UNIBTA
# 701720    261.0             261.0            None      UNIBTA
# 701721    261.0             261.0            None      UNIBTA
# 701722    261.0             261.0            None      UNIBTA
# 701723    261.0             261.0            None      UNIBTA
# 701724    261.0             261.0            None      UNIBTA
# 701725    261.0             261.0            None      UNIBTA
# 701726    303.0             303.0            None      UNIBTA
# 701727    303.0             303.0            None      UNIBTA
# 701728    303.0             303.0            None      UNIBTA
# 701729    303.0             303.0            None      UNIBTA
# 701730    303.0             303.0            None      UNIBTA
# 701731    271.0             271.0            None      UNIBTA
# 701732    159.0             159.0            None      UNIBTA
# 701733    261.0             261.0            None      UNIBTA
# 701734    261.0             261.0            None      UNIBTA
# 701735    261.0             261.0            None      UNIBTA
# 701736    261.0             261.0            None      UNIBTA
# 701737    261.0             261.0            None      UNIBTA
# 701738    303.0             303.0            None      UNIBTA
# 701739    303.0             303.0            None      UNIBTA
# 701740    303.0             303.0            None      UNIBTA
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 701711               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701712               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701713               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701714               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701715               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701716               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701717               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701718               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701719               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701720               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701721               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701722               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701723               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701724               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701725               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701726               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701727               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701728               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701729               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701730               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701731               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701732               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701733               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701734               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701735               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701736               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701737               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701738               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701739               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701740               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#         CIDADE_UF_DF  NOME_LOCAL_PARA  GRUPO_PARA  MARCA_PARA
# 0                 NI              NaN         NaN         NaN
# 1                 NI              NaN         NaN         NaN
# 2                 NI              NaN         NaN         NaN
# 3                 NI              NaN         NaN         NaN
# 4                 NI              NaN         NaN         NaN
# 5                 NI              NaN         NaN         NaN
# 6                 NI              NaN         NaN         NaN
# 7                 NI              NaN         NaN         NaN
# 8                 NI              NaN         NaN         NaN
# 9                 NI              NaN         NaN         NaN
# 10                NI              NaN         NaN         NaN
# 11                NI              NaN         NaN         NaN
# 12                NI              NaN         NaN         NaN
# 13                NI              NaN         NaN         NaN
# 14                NI              NaN         NaN         NaN
# 15                NI              NaN         NaN         NaN
# 16                NI              NaN         NaN         NaN
# 17                NI              NaN         NaN         NaN
# 18                NI              NaN         NaN         NaN
# 19                NI              NaN         NaN         NaN
# 20                NI              NaN         NaN         NaN
# 21                NI              NaN         NaN         NaN
# 22                NI              NaN         NaN         NaN
# 23                NI              NaN         NaN         NaN
# 24                NI              NaN         NaN         NaN
# 25                NI              NaN         NaN         NaN
# 26                NI              NaN         NaN         NaN
# 27                NI              NaN         NaN         NaN
# 28                NI              NaN         NaN         NaN
# 29                NI              NaN         NaN         NaN
# ...              ...              ...         ...         ...
# 701711            NI              NaN         NaN         NaN
# 701712            NI              NaN         NaN         NaN
# 701713            NI              NaN         NaN         NaN
# 701714            NI              NaN         NaN         NaN
# 701715            NI              NaN         NaN         NaN
# 701716            NI              NaN         NaN         NaN
# 701717            NI              NaN         NaN         NaN
# 701718            NI              NaN         NaN         NaN
# 701719            NI              NaN         NaN         NaN
# 701720            NI              NaN         NaN         NaN
# 701721            NI              NaN         NaN         NaN
# 701722            NI              NaN         NaN         NaN
# 701723            NI              NaN         NaN         NaN
# 701724            NI              NaN         NaN         NaN
# 701725            NI              NaN         NaN         NaN
# 701726            NI              NaN         NaN         NaN
# 701727            NI              NaN         NaN         NaN
# 701728            NI              NaN         NaN         NaN
# 701729            NI              NaN         NaN         NaN
# 701730            NI              NaN         NaN         NaN
# 701731            NI              NaN         NaN         NaN
# 701732            NI              NaN         NaN         NaN
# 701733            NI              NaN         NaN         NaN
# 701734            NI              NaN         NaN         NaN
# 701735            NI              NaN         NaN         NaN
# 701736            NI              NaN         NaN         NaN
# 701737            NI              NaN         NaN         NaN
# 701738            NI              NaN         NaN         NaN
# 701739            NI              NaN         NaN         NaN
# 701740            NI              NaN         NaN         NaN
#
# [701741 rows x 56 columns]

# %%
rft["NOME_LOCAL_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"NOME_LOCAL_PARA": "NOME_LOCAL_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 701711  19943850 2019-02-04       UNIBTA         None
# 701712  19943851 2019-02-04       UNIBTA         None
# 701713  19943852 2019-02-04       UNIBTA         None
# 701714  19943853 2019-02-04       UNIBTA         None
# 701715  19943854 2019-02-04       UNIBTA         None
# 701716  19943855 2019-02-04       UNIBTA         None
# 701717  19943856 2019-02-04       UNIBTA         None
# 701718  19943857 2019-02-04       UNIBTA         None
# 701719  19943858 2019-02-04       UNIBTA         None
# 701720  19943859 2019-02-04       UNIBTA         None
# 701721  19943860 2019-02-04       UNIBTA         None
# 701722  19943861 2019-02-04       UNIBTA         None
# 701723  19943862 2019-02-04       UNIBTA         None
# 701724  19943863 2019-02-04       UNIBTA         None
# 701725  19943864 2019-02-04       UNIBTA         None
# 701726  19943865 2019-02-04       UNIBTA         None
# 701727  19943866 2019-02-04       UNIBTA         None
# 701728  19943867 2019-02-04       UNIBTA         None
# 701729  19943868 2019-02-04       UNIBTA         None
# 701730  19943869 2019-02-04       UNIBTA         None
# 701731  19943870 2019-02-04       UNIBTA         None
# 701732  19943871 2019-02-04       UNIBTA         None
# 701733  19943872 2019-02-04       UNIBTA         None
# 701734  19943873 2019-02-04       UNIBTA         None
# 701735  19943874 2019-02-04       UNIBTA         None
# 701736  19943875 2019-02-04       UNIBTA         None
# 701737  19943876 2019-02-04       UNIBTA         None
# 701738  19943877 2019-02-04       UNIBTA         None
# 701739  19943878 2019-02-04       UNIBTA         None
# 701740  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 701711           Tecnólogo em Marketing Digital                EAD
# 701712           Tecnólogo em Segurança Pública                EAD
# 701713      Tecnólogo em Sistemas para Internet                EAD
# 701714                            Administração                EAD
# 701715                       Ciências Contábeis                EAD
# 701716                          Educação Física                EAD
# 701717              Letras - Português e Inglês                EAD
# 701718                                Pedagogia                EAD
# 701719            Tecnólogo em Gestão Comercial                EAD
# 701720  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701721           Tecnólogo em Gestão Financeira                EAD
# 701722              Tecnólogo em Gestão Pública                EAD
# 701723           Tecnólogo em Marketing Digital                EAD
# 701724           Tecnólogo em Segurança Pública                EAD
# 701725      Tecnólogo em Sistemas para Internet                EAD
# 701726                            Administração                EAD
# 701727                       Ciências Contábeis                EAD
# 701728                          Educação Física                EAD
# 701729              Letras - Português e Inglês                EAD
# 701730                                Pedagogia                EAD
# 701731            Tecnólogo em Gestão Comercial                EAD
# 701732  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701733           Tecnólogo em Gestão Financeira                EAD
# 701734              Tecnólogo em Gestão Pública                EAD
# 701735           Tecnólogo em Marketing Digital                EAD
# 701736           Tecnólogo em Segurança Pública                EAD
# 701737      Tecnólogo em Sistemas para Internet                EAD
# 701738                            Administração                EAD
# 701739                       Ciências Contábeis                EAD
# 701740                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID     ...      \
# 0             Tecnólogo          BA            BA       None     ...
# 1             Tecnólogo          RS            RS       None     ...
# 2             Tecnólogo          PA            PA       None     ...
# 3             Tecnólogo          SP            SP       None     ...
# 4             Tecnólogo          SP            SP       None     ...
# 5             Tecnólogo          SP            SP       None     ...
# 6             Tecnólogo          RO            RO       None     ...
# 7             Tecnólogo          SP            SP       None     ...
# 8             Tecnólogo          SP            SP       None     ...
# 9             Tecnólogo          MA            MA       None     ...
# 10            Tecnólogo          RO            RO       None     ...
# 11            Tecnólogo          SP            SP       None     ...
# 12            Tecnólogo          SP            SP       None     ...
# 13            Tecnólogo          SP            SP       None     ...
# 14            Tecnólogo          PE            PE       None     ...
# 15            Tecnólogo          MT            MT       None     ...
# 16            Tecnólogo          CE            CE       None     ...
# 17            Tecnólogo          SP            SP       None     ...
# 18            Tecnólogo          AM            AM       None     ...
# 19            Tecnólogo          DF            DF       None     ...
# 20            Tecnólogo          DF            DF       None     ...
# 21            Tecnólogo          PI            PI       None     ...
# 22            Tecnólogo          MG            MG       None     ...
# 23            Tecnólogo          MG            MG       None     ...
# 24            Tecnólogo          RO            RO       None     ...
# 25            Tecnólogo          ES            ES       None     ...
# 26            Tecnólogo          BA            BA       None     ...
# 27            Tecnólogo          RJ            RJ       None     ...
# 28            Tecnólogo          GO            GO       None     ...
# 29            Tecnólogo          SE            SE       None     ...
# ...                 ...         ...           ...        ...     ...
# 701711             None        None            CE       None     ...
# 701712             None        None            CE       None     ...
# 701713             None        None            CE       None     ...
# 701714             None        None            CE       None     ...
# 701715             None        None            CE       None     ...
# 701716             None        None            CE       None     ...
# 701717             None        None            CE       None     ...
# 701718             None        None            CE       None     ...
# 701719             None        None            CE       None     ...
# 701720             None        None            CE       None     ...
# 701721             None        None            CE       None     ...
# 701722             None        None            CE       None     ...
# 701723             None        None            CE       None     ...
# 701724             None        None            CE       None     ...
# 701725             None        None            CE       None     ...
# 701726             None        None            CE       None     ...
# 701727             None        None            CE       None     ...
# 701728             None        None            CE       None     ...
# 701729             None        None            CE       None     ...
# 701730             None        None            CE       None     ...
# 701731             None        None            CE       None     ...
# 701732             None        None            CE       None     ...
# 701733             None        None            CE       None     ...
# 701734             None        None            CE       None     ...
# 701735             None        None            CE       None     ...
# 701736             None        None            CE       None     ...
# 701737             None        None            CE       None     ...
# 701738             None        None            CE       None     ...
# 701739             None        None            CE       None     ...
# 701740             None        None            CE       None     ...
#
#        PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0        461.11            461.11            None  CLARETIANO
# 1        461.11            461.11            None  CLARETIANO
# 2        461.11            461.11            None  CLARETIANO
# 3        461.11            461.11            None  CLARETIANO
# 4        461.11            461.11            None  CLARETIANO
# 5        461.11            461.11            None  CLARETIANO
# 6        461.11            461.11            None  CLARETIANO
# 7        461.11            461.11            None  CLARETIANO
# 8        461.11            461.11            None  CLARETIANO
# 9        461.11            461.11            None  CLARETIANO
# 10       461.11            461.11            None  CLARETIANO
# 11       461.11            461.11            None  CLARETIANO
# 12       461.11            461.11            None  CLARETIANO
# 13       482.22            482.22            None  CLARETIANO
# 14       461.11            461.11            None  CLARETIANO
# 15       461.11            461.11            None  CLARETIANO
# 16       461.11            461.11            None  CLARETIANO
# 17       461.11            461.11            None  CLARETIANO
# 18       461.11            461.11            None  CLARETIANO
# 19       461.11            461.11            None  CLARETIANO
# 20       482.22            482.22            None  CLARETIANO
# 21       461.11            461.11            None  CLARETIANO
# 22       461.11            461.11            None  CLARETIANO
# 23       461.11            461.11            None  CLARETIANO
# 24       461.11            461.11            None  CLARETIANO
# 25       461.11            461.11            None  CLARETIANO
# 26       461.11            461.11            None  CLARETIANO
# 27       461.11            461.11            None  CLARETIANO
# 28       277.78            277.78            None  CLARETIANO
# 29       277.78            277.78            None  CLARETIANO
# ...         ...               ...             ...         ...
# 701711    261.0             261.0            None      UNIBTA
# 701712    261.0             261.0            None      UNIBTA
# 701713    261.0             261.0            None      UNIBTA
# 701714    303.0             303.0            None      UNIBTA
# 701715    303.0             303.0            None      UNIBTA
# 701716    303.0             303.0            None      UNIBTA
# 701717    303.0             303.0            None      UNIBTA
# 701718    271.0             271.0            None      UNIBTA
# 701719    159.0             159.0            None      UNIBTA
# 701720    261.0             261.0            None      UNIBTA
# 701721    261.0             261.0            None      UNIBTA
# 701722    261.0             261.0            None      UNIBTA
# 701723    261.0             261.0            None      UNIBTA
# 701724    261.0             261.0            None      UNIBTA
# 701725    261.0             261.0            None      UNIBTA
# 701726    303.0             303.0            None      UNIBTA
# 701727    303.0             303.0            None      UNIBTA
# 701728    303.0             303.0            None      UNIBTA
# 701729    303.0             303.0            None      UNIBTA
# 701730    303.0             303.0            None      UNIBTA
# 701731    271.0             271.0            None      UNIBTA
# 701732    159.0             159.0            None      UNIBTA
# 701733    261.0             261.0            None      UNIBTA
# 701734    261.0             261.0            None      UNIBTA
# 701735    261.0             261.0            None      UNIBTA
# 701736    261.0             261.0            None      UNIBTA
# 701737    261.0             261.0            None      UNIBTA
# 701738    303.0             303.0            None      UNIBTA
# 701739    303.0             303.0            None      UNIBTA
# 701740    303.0             303.0            None      UNIBTA
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 701711               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701712               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701713               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701714               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701715               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701716               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701717               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701718               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701719               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701720               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701721               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701722               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701723               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701724               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701725               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701726               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701727               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701728               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701729               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701730               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701731               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701732               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701733               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701734               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701735               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701736               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701737               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701738               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701739               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701740               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#         CIDADE_PARA  NOME_LOCAL_DF  GRUPO_PARA  MARCA_PARA
# 0                NI             NI         NaN         NaN
# 1                NI             NI         NaN         NaN
# 2                NI             NI         NaN         NaN
# 3                NI             NI         NaN         NaN
# 4                NI             NI         NaN         NaN
# 5                NI             NI         NaN         NaN
# 6                NI             NI         NaN         NaN
# 7                NI             NI         NaN         NaN
# 8                NI             NI         NaN         NaN
# 9                NI             NI         NaN         NaN
# 10               NI             NI         NaN         NaN
# 11               NI             NI         NaN         NaN
# 12               NI             NI         NaN         NaN
# 13               NI             NI         NaN         NaN
# 14               NI             NI         NaN         NaN
# 15               NI             NI         NaN         NaN
# 16               NI             NI         NaN         NaN
# 17               NI             NI         NaN         NaN
# 18               NI             NI         NaN         NaN
# 19               NI             NI         NaN         NaN
# 20               NI             NI         NaN         NaN
# 21               NI             NI         NaN         NaN
# 22               NI             NI         NaN         NaN
# 23               NI             NI         NaN         NaN
# 24               NI             NI         NaN         NaN
# 25               NI             NI         NaN         NaN
# 26               NI             NI         NaN         NaN
# 27               NI             NI         NaN         NaN
# 28               NI             NI         NaN         NaN
# 29               NI             NI         NaN         NaN
# ...             ...            ...         ...         ...
# 701711           NI             NI         NaN         NaN
# 701712           NI             NI         NaN         NaN
# 701713           NI             NI         NaN         NaN
# 701714           NI             NI         NaN         NaN
# 701715           NI             NI         NaN         NaN
# 701716           NI             NI         NaN         NaN
# 701717           NI             NI         NaN         NaN
# 701718           NI             NI         NaN         NaN
# 701719           NI             NI         NaN         NaN
# 701720           NI             NI         NaN         NaN
# 701721           NI             NI         NaN         NaN
# 701722           NI             NI         NaN         NaN
# 701723           NI             NI         NaN         NaN
# 701724           NI             NI         NaN         NaN
# 701725           NI             NI         NaN         NaN
# 701726           NI             NI         NaN         NaN
# 701727           NI             NI         NaN         NaN
# 701728           NI             NI         NaN         NaN
# 701729           NI             NI         NaN         NaN
# 701730           NI             NI         NaN         NaN
# 701731           NI             NI         NaN         NaN
# 701732           NI             NI         NaN         NaN
# 701733           NI             NI         NaN         NaN
# 701734           NI             NI         NaN         NaN
# 701735           NI             NI         NaN         NaN
# 701736           NI             NI         NaN         NaN
# 701737           NI             NI         NaN         NaN
# 701738           NI             NI         NaN         NaN
# 701739           NI             NI         NaN         NaN
# 701740           NI             NI         NaN         NaN
#
# [701741 rows x 56 columns]

# %%
rft["GRUPO_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"GRUPO_PARA": "GRUPO_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 701711  19943850 2019-02-04       UNIBTA         None
# 701712  19943851 2019-02-04       UNIBTA         None
# 701713  19943852 2019-02-04       UNIBTA         None
# 701714  19943853 2019-02-04       UNIBTA         None
# 701715  19943854 2019-02-04       UNIBTA         None
# 701716  19943855 2019-02-04       UNIBTA         None
# 701717  19943856 2019-02-04       UNIBTA         None
# 701718  19943857 2019-02-04       UNIBTA         None
# 701719  19943858 2019-02-04       UNIBTA         None
# 701720  19943859 2019-02-04       UNIBTA         None
# 701721  19943860 2019-02-04       UNIBTA         None
# 701722  19943861 2019-02-04       UNIBTA         None
# 701723  19943862 2019-02-04       UNIBTA         None
# 701724  19943863 2019-02-04       UNIBTA         None
# 701725  19943864 2019-02-04       UNIBTA         None
# 701726  19943865 2019-02-04       UNIBTA         None
# 701727  19943866 2019-02-04       UNIBTA         None
# 701728  19943867 2019-02-04       UNIBTA         None
# 701729  19943868 2019-02-04       UNIBTA         None
# 701730  19943869 2019-02-04       UNIBTA         None
# 701731  19943870 2019-02-04       UNIBTA         None
# 701732  19943871 2019-02-04       UNIBTA         None
# 701733  19943872 2019-02-04       UNIBTA         None
# 701734  19943873 2019-02-04       UNIBTA         None
# 701735  19943874 2019-02-04       UNIBTA         None
# 701736  19943875 2019-02-04       UNIBTA         None
# 701737  19943876 2019-02-04       UNIBTA         None
# 701738  19943877 2019-02-04       UNIBTA         None
# 701739  19943878 2019-02-04       UNIBTA         None
# 701740  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 701711           Tecnólogo em Marketing Digital                EAD
# 701712           Tecnólogo em Segurança Pública                EAD
# 701713      Tecnólogo em Sistemas para Internet                EAD
# 701714                            Administração                EAD
# 701715                       Ciências Contábeis                EAD
# 701716                          Educação Física                EAD
# 701717              Letras - Português e Inglês                EAD
# 701718                                Pedagogia                EAD
# 701719            Tecnólogo em Gestão Comercial                EAD
# 701720  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701721           Tecnólogo em Gestão Financeira                EAD
# 701722              Tecnólogo em Gestão Pública                EAD
# 701723           Tecnólogo em Marketing Digital                EAD
# 701724           Tecnólogo em Segurança Pública                EAD
# 701725      Tecnólogo em Sistemas para Internet                EAD
# 701726                            Administração                EAD
# 701727                       Ciências Contábeis                EAD
# 701728                          Educação Física                EAD
# 701729              Letras - Português e Inglês                EAD
# 701730                                Pedagogia                EAD
# 701731            Tecnólogo em Gestão Comercial                EAD
# 701732  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701733           Tecnólogo em Gestão Financeira                EAD
# 701734              Tecnólogo em Gestão Pública                EAD
# 701735           Tecnólogo em Marketing Digital                EAD
# 701736           Tecnólogo em Segurança Pública                EAD
# 701737      Tecnólogo em Sistemas para Internet                EAD
# 701738                            Administração                EAD
# 701739                       Ciências Contábeis                EAD
# 701740                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID     ...      \
# 0             Tecnólogo          BA            BA       None     ...
# 1             Tecnólogo          RS            RS       None     ...
# 2             Tecnólogo          PA            PA       None     ...
# 3             Tecnólogo          SP            SP       None     ...
# 4             Tecnólogo          SP            SP       None     ...
# 5             Tecnólogo          SP            SP       None     ...
# 6             Tecnólogo          RO            RO       None     ...
# 7             Tecnólogo          SP            SP       None     ...
# 8             Tecnólogo          SP            SP       None     ...
# 9             Tecnólogo          MA            MA       None     ...
# 10            Tecnólogo          RO            RO       None     ...
# 11            Tecnólogo          SP            SP       None     ...
# 12            Tecnólogo          SP            SP       None     ...
# 13            Tecnólogo          SP            SP       None     ...
# 14            Tecnólogo          PE            PE       None     ...
# 15            Tecnólogo          MT            MT       None     ...
# 16            Tecnólogo          CE            CE       None     ...
# 17            Tecnólogo          SP            SP       None     ...
# 18            Tecnólogo          AM            AM       None     ...
# 19            Tecnólogo          DF            DF       None     ...
# 20            Tecnólogo          DF            DF       None     ...
# 21            Tecnólogo          PI            PI       None     ...
# 22            Tecnólogo          MG            MG       None     ...
# 23            Tecnólogo          MG            MG       None     ...
# 24            Tecnólogo          RO            RO       None     ...
# 25            Tecnólogo          ES            ES       None     ...
# 26            Tecnólogo          BA            BA       None     ...
# 27            Tecnólogo          RJ            RJ       None     ...
# 28            Tecnólogo          GO            GO       None     ...
# 29            Tecnólogo          SE            SE       None     ...
# ...                 ...         ...           ...        ...     ...
# 701711             None        None            CE       None     ...
# 701712             None        None            CE       None     ...
# 701713             None        None            CE       None     ...
# 701714             None        None            CE       None     ...
# 701715             None        None            CE       None     ...
# 701716             None        None            CE       None     ...
# 701717             None        None            CE       None     ...
# 701718             None        None            CE       None     ...
# 701719             None        None            CE       None     ...
# 701720             None        None            CE       None     ...
# 701721             None        None            CE       None     ...
# 701722             None        None            CE       None     ...
# 701723             None        None            CE       None     ...
# 701724             None        None            CE       None     ...
# 701725             None        None            CE       None     ...
# 701726             None        None            CE       None     ...
# 701727             None        None            CE       None     ...
# 701728             None        None            CE       None     ...
# 701729             None        None            CE       None     ...
# 701730             None        None            CE       None     ...
# 701731             None        None            CE       None     ...
# 701732             None        None            CE       None     ...
# 701733             None        None            CE       None     ...
# 701734             None        None            CE       None     ...
# 701735             None        None            CE       None     ...
# 701736             None        None            CE       None     ...
# 701737             None        None            CE       None     ...
# 701738             None        None            CE       None     ...
# 701739             None        None            CE       None     ...
# 701740             None        None            CE       None     ...
#
#        PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0        461.11            461.11            None  CLARETIANO
# 1        461.11            461.11            None  CLARETIANO
# 2        461.11            461.11            None  CLARETIANO
# 3        461.11            461.11            None  CLARETIANO
# 4        461.11            461.11            None  CLARETIANO
# 5        461.11            461.11            None  CLARETIANO
# 6        461.11            461.11            None  CLARETIANO
# 7        461.11            461.11            None  CLARETIANO
# 8        461.11            461.11            None  CLARETIANO
# 9        461.11            461.11            None  CLARETIANO
# 10       461.11            461.11            None  CLARETIANO
# 11       461.11            461.11            None  CLARETIANO
# 12       461.11            461.11            None  CLARETIANO
# 13       482.22            482.22            None  CLARETIANO
# 14       461.11            461.11            None  CLARETIANO
# 15       461.11            461.11            None  CLARETIANO
# 16       461.11            461.11            None  CLARETIANO
# 17       461.11            461.11            None  CLARETIANO
# 18       461.11            461.11            None  CLARETIANO
# 19       461.11            461.11            None  CLARETIANO
# 20       482.22            482.22            None  CLARETIANO
# 21       461.11            461.11            None  CLARETIANO
# 22       461.11            461.11            None  CLARETIANO
# 23       461.11            461.11            None  CLARETIANO
# 24       461.11            461.11            None  CLARETIANO
# 25       461.11            461.11            None  CLARETIANO
# 26       461.11            461.11            None  CLARETIANO
# 27       461.11            461.11            None  CLARETIANO
# 28       277.78            277.78            None  CLARETIANO
# 29       277.78            277.78            None  CLARETIANO
# ...         ...               ...             ...         ...
# 701711    261.0             261.0            None      UNIBTA
# 701712    261.0             261.0            None      UNIBTA
# 701713    261.0             261.0            None      UNIBTA
# 701714    303.0             303.0            None      UNIBTA
# 701715    303.0             303.0            None      UNIBTA
# 701716    303.0             303.0            None      UNIBTA
# 701717    303.0             303.0            None      UNIBTA
# 701718    271.0             271.0            None      UNIBTA
# 701719    159.0             159.0            None      UNIBTA
# 701720    261.0             261.0            None      UNIBTA
# 701721    261.0             261.0            None      UNIBTA
# 701722    261.0             261.0            None      UNIBTA
# 701723    261.0             261.0            None      UNIBTA
# 701724    261.0             261.0            None      UNIBTA
# 701725    261.0             261.0            None      UNIBTA
# 701726    303.0             303.0            None      UNIBTA
# 701727    303.0             303.0            None      UNIBTA
# 701728    303.0             303.0            None      UNIBTA
# 701729    303.0             303.0            None      UNIBTA
# 701730    303.0             303.0            None      UNIBTA
# 701731    271.0             271.0            None      UNIBTA
# 701732    159.0             159.0            None      UNIBTA
# 701733    261.0             261.0            None      UNIBTA
# 701734    261.0             261.0            None      UNIBTA
# 701735    261.0             261.0            None      UNIBTA
# 701736    261.0             261.0            None      UNIBTA
# 701737    261.0             261.0            None      UNIBTA
# 701738    303.0             303.0            None      UNIBTA
# 701739    303.0             303.0            None      UNIBTA
# 701740    303.0             303.0            None      UNIBTA
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 701711               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701712               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701713               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701714               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701715               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701716               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701717               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701718               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701719               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701720               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701721               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701722               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701723               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701724               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701725               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701726               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701727               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701728               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701729               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701730               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701731               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701732               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701733               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701734               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701735               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701736               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701737               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701738               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701739               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701740               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#         CIDADE_PARA  NOME_LOCAL_PARA  GRUPO_DF  MARCA_PARA
# 0                NI               NI        NI         NaN
# 1                NI               NI        NI         NaN
# 2                NI               NI        NI         NaN
# 3                NI               NI        NI         NaN
# 4                NI               NI        NI         NaN
# 5                NI               NI        NI         NaN
# 6                NI               NI        NI         NaN
# 7                NI               NI        NI         NaN
# 8                NI               NI        NI         NaN
# 9                NI               NI        NI         NaN
# 10               NI               NI        NI         NaN
# 11               NI               NI        NI         NaN
# 12               NI               NI        NI         NaN
# 13               NI               NI        NI         NaN
# 14               NI               NI        NI         NaN
# 15               NI               NI        NI         NaN
# 16               NI               NI        NI         NaN
# 17               NI               NI        NI         NaN
# 18               NI               NI        NI         NaN
# 19               NI               NI        NI         NaN
# 20               NI               NI        NI         NaN
# 21               NI               NI        NI         NaN
# 22               NI               NI        NI         NaN
# 23               NI               NI        NI         NaN
# 24               NI               NI        NI         NaN
# 25               NI               NI        NI         NaN
# 26               NI               NI        NI         NaN
# 27               NI               NI        NI         NaN
# 28               NI               NI        NI         NaN
# 29               NI               NI        NI         NaN
# ...             ...              ...       ...         ...
# 701711           NI               NI        NI         NaN
# 701712           NI               NI        NI         NaN
# 701713           NI               NI        NI         NaN
# 701714           NI               NI        NI         NaN
# 701715           NI               NI        NI         NaN
# 701716           NI               NI        NI         NaN
# 701717           NI               NI        NI         NaN
# 701718           NI               NI        NI         NaN
# 701719           NI               NI        NI         NaN
# 701720           NI               NI        NI         NaN
# 701721           NI               NI        NI         NaN
# 701722           NI               NI        NI         NaN
# 701723           NI               NI        NI         NaN
# 701724           NI               NI        NI         NaN
# 701725           NI               NI        NI         NaN
# 701726           NI               NI        NI         NaN
# 701727           NI               NI        NI         NaN
# 701728           NI               NI        NI         NaN
# 701729           NI               NI        NI         NaN
# 701730           NI               NI        NI         NaN
# 701731           NI               NI        NI         NaN
# 701732           NI               NI        NI         NaN
# 701733           NI               NI        NI         NaN
# 701734           NI               NI        NI         NaN
# 701735           NI               NI        NI         NaN
# 701736           NI               NI        NI         NaN
# 701737           NI               NI        NI         NaN
# 701738           NI               NI        NI         NaN
# 701739           NI               NI        NI         NaN
# 701740           NI               NI        NI         NaN
#
# [701741 rows x 56 columns]

# %%
rft["MARCA_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"MARCA_PARA": "MARCA_PARA_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 701711  19943850 2019-02-04       UNIBTA         None
# 701712  19943851 2019-02-04       UNIBTA         None
# 701713  19943852 2019-02-04       UNIBTA         None
# 701714  19943853 2019-02-04       UNIBTA         None
# 701715  19943854 2019-02-04       UNIBTA         None
# 701716  19943855 2019-02-04       UNIBTA         None
# 701717  19943856 2019-02-04       UNIBTA         None
# 701718  19943857 2019-02-04       UNIBTA         None
# 701719  19943858 2019-02-04       UNIBTA         None
# 701720  19943859 2019-02-04       UNIBTA         None
# 701721  19943860 2019-02-04       UNIBTA         None
# 701722  19943861 2019-02-04       UNIBTA         None
# 701723  19943862 2019-02-04       UNIBTA         None
# 701724  19943863 2019-02-04       UNIBTA         None
# 701725  19943864 2019-02-04       UNIBTA         None
# 701726  19943865 2019-02-04       UNIBTA         None
# 701727  19943866 2019-02-04       UNIBTA         None
# 701728  19943867 2019-02-04       UNIBTA         None
# 701729  19943868 2019-02-04       UNIBTA         None
# 701730  19943869 2019-02-04       UNIBTA         None
# 701731  19943870 2019-02-04       UNIBTA         None
# 701732  19943871 2019-02-04       UNIBTA         None
# 701733  19943872 2019-02-04       UNIBTA         None
# 701734  19943873 2019-02-04       UNIBTA         None
# 701735  19943874 2019-02-04       UNIBTA         None
# 701736  19943875 2019-02-04       UNIBTA         None
# 701737  19943876 2019-02-04       UNIBTA         None
# 701738  19943877 2019-02-04       UNIBTA         None
# 701739  19943878 2019-02-04       UNIBTA         None
# 701740  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 701711           Tecnólogo em Marketing Digital                EAD
# 701712           Tecnólogo em Segurança Pública                EAD
# 701713      Tecnólogo em Sistemas para Internet                EAD
# 701714                            Administração                EAD
# 701715                       Ciências Contábeis                EAD
# 701716                          Educação Física                EAD
# 701717              Letras - Português e Inglês                EAD
# 701718                                Pedagogia                EAD
# 701719            Tecnólogo em Gestão Comercial                EAD
# 701720  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701721           Tecnólogo em Gestão Financeira                EAD
# 701722              Tecnólogo em Gestão Pública                EAD
# 701723           Tecnólogo em Marketing Digital                EAD
# 701724           Tecnólogo em Segurança Pública                EAD
# 701725      Tecnólogo em Sistemas para Internet                EAD
# 701726                            Administração                EAD
# 701727                       Ciências Contábeis                EAD
# 701728                          Educação Física                EAD
# 701729              Letras - Português e Inglês                EAD
# 701730                                Pedagogia                EAD
# 701731            Tecnólogo em Gestão Comercial                EAD
# 701732  Tecnólogo em Gestão de Recursos Humanos                EAD
# 701733           Tecnólogo em Gestão Financeira                EAD
# 701734              Tecnólogo em Gestão Pública                EAD
# 701735           Tecnólogo em Marketing Digital                EAD
# 701736           Tecnólogo em Segurança Pública                EAD
# 701737      Tecnólogo em Sistemas para Internet                EAD
# 701738                            Administração                EAD
# 701739                       Ciências Contábeis                EAD
# 701740                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID      ...        \
# 0             Tecnólogo          BA            BA       None      ...
# 1             Tecnólogo          RS            RS       None      ...
# 2             Tecnólogo          PA            PA       None      ...
# 3             Tecnólogo          SP            SP       None      ...
# 4             Tecnólogo          SP            SP       None      ...
# 5             Tecnólogo          SP            SP       None      ...
# 6             Tecnólogo          RO            RO       None      ...
# 7             Tecnólogo          SP            SP       None      ...
# 8             Tecnólogo          SP            SP       None      ...
# 9             Tecnólogo          MA            MA       None      ...
# 10            Tecnólogo          RO            RO       None      ...
# 11            Tecnólogo          SP            SP       None      ...
# 12            Tecnólogo          SP            SP       None      ...
# 13            Tecnólogo          SP            SP       None      ...
# 14            Tecnólogo          PE            PE       None      ...
# 15            Tecnólogo          MT            MT       None      ...
# 16            Tecnólogo          CE            CE       None      ...
# 17            Tecnólogo          SP            SP       None      ...
# 18            Tecnólogo          AM            AM       None      ...
# 19            Tecnólogo          DF            DF       None      ...
# 20            Tecnólogo          DF            DF       None      ...
# 21            Tecnólogo          PI            PI       None      ...
# 22            Tecnólogo          MG            MG       None      ...
# 23            Tecnólogo          MG            MG       None      ...
# 24            Tecnólogo          RO            RO       None      ...
# 25            Tecnólogo          ES            ES       None      ...
# 26            Tecnólogo          BA            BA       None      ...
# 27            Tecnólogo          RJ            RJ       None      ...
# 28            Tecnólogo          GO            GO       None      ...
# 29            Tecnólogo          SE            SE       None      ...
# ...                 ...         ...           ...        ...      ...
# 701711             None        None            CE       None      ...
# 701712             None        None            CE       None      ...
# 701713             None        None            CE       None      ...
# 701714             None        None            CE       None      ...
# 701715             None        None            CE       None      ...
# 701716             None        None            CE       None      ...
# 701717             None        None            CE       None      ...
# 701718             None        None            CE       None      ...
# 701719             None        None            CE       None      ...
# 701720             None        None            CE       None      ...
# 701721             None        None            CE       None      ...
# 701722             None        None            CE       None      ...
# 701723             None        None            CE       None      ...
# 701724             None        None            CE       None      ...
# 701725             None        None            CE       None      ...
# 701726             None        None            CE       None      ...
# 701727             None        None            CE       None      ...
# 701728             None        None            CE       None      ...
# 701729             None        None            CE       None      ...
# 701730             None        None            CE       None      ...
# 701731             None        None            CE       None      ...
# 701732             None        None            CE       None      ...
# 701733             None        None            CE       None      ...
# 701734             None        None            CE       None      ...
# 701735             None        None            CE       None      ...
# 701736             None        None            CE       None      ...
# 701737             None        None            CE       None      ...
# 701738             None        None            CE       None      ...
# 701739             None        None            CE       None      ...
# 701740             None        None            CE       None      ...
#
#        PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0        461.11            461.11            None  CLARETIANO
# 1        461.11            461.11            None  CLARETIANO
# 2        461.11            461.11            None  CLARETIANO
# 3        461.11            461.11            None  CLARETIANO
# 4        461.11            461.11            None  CLARETIANO
# 5        461.11            461.11            None  CLARETIANO
# 6        461.11            461.11            None  CLARETIANO
# 7        461.11            461.11            None  CLARETIANO
# 8        461.11            461.11            None  CLARETIANO
# 9        461.11            461.11            None  CLARETIANO
# 10       461.11            461.11            None  CLARETIANO
# 11       461.11            461.11            None  CLARETIANO
# 12       461.11            461.11            None  CLARETIANO
# 13       482.22            482.22            None  CLARETIANO
# 14       461.11            461.11            None  CLARETIANO
# 15       461.11            461.11            None  CLARETIANO
# 16       461.11            461.11            None  CLARETIANO
# 17       461.11            461.11            None  CLARETIANO
# 18       461.11            461.11            None  CLARETIANO
# 19       461.11            461.11            None  CLARETIANO
# 20       482.22            482.22            None  CLARETIANO
# 21       461.11            461.11            None  CLARETIANO
# 22       461.11            461.11            None  CLARETIANO
# 23       461.11            461.11            None  CLARETIANO
# 24       461.11            461.11            None  CLARETIANO
# 25       461.11            461.11            None  CLARETIANO
# 26       461.11            461.11            None  CLARETIANO
# 27       461.11            461.11            None  CLARETIANO
# 28       277.78            277.78            None  CLARETIANO
# 29       277.78            277.78            None  CLARETIANO
# ...         ...               ...             ...         ...
# 701711    261.0             261.0            None      UNIBTA
# 701712    261.0             261.0            None      UNIBTA
# 701713    261.0             261.0            None      UNIBTA
# 701714    303.0             303.0            None      UNIBTA
# 701715    303.0             303.0            None      UNIBTA
# 701716    303.0             303.0            None      UNIBTA
# 701717    303.0             303.0            None      UNIBTA
# 701718    271.0             271.0            None      UNIBTA
# 701719    159.0             159.0            None      UNIBTA
# 701720    261.0             261.0            None      UNIBTA
# 701721    261.0             261.0            None      UNIBTA
# 701722    261.0             261.0            None      UNIBTA
# 701723    261.0             261.0            None      UNIBTA
# 701724    261.0             261.0            None      UNIBTA
# 701725    261.0             261.0            None      UNIBTA
# 701726    303.0             303.0            None      UNIBTA
# 701727    303.0             303.0            None      UNIBTA
# 701728    303.0             303.0            None      UNIBTA
# 701729    303.0             303.0            None      UNIBTA
# 701730    303.0             303.0            None      UNIBTA
# 701731    271.0             271.0            None      UNIBTA
# 701732    159.0             159.0            None      UNIBTA
# 701733    261.0             261.0            None      UNIBTA
# 701734    261.0             261.0            None      UNIBTA
# 701735    261.0             261.0            None      UNIBTA
# 701736    261.0             261.0            None      UNIBTA
# 701737    261.0             261.0            None      UNIBTA
# 701738    303.0             303.0            None      UNIBTA
# 701739    303.0             303.0            None      UNIBTA
# 701740    303.0             303.0            None      UNIBTA
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 701711               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701712               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701713               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 701714               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701715               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701716               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701717               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701718               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701719               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701720               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701721               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701722               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701723               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701724               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701725               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 701726               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701727               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701728               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701729               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701730               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701731               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701732               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701733               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701734               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701735               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701736               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701737               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 701738               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701739               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 701740               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#         CIDADE_PARA  NOME_LOCAL_PARA  GRUPO_PARA  MARCA_PARA_DF
# 0                NI               NI          NI             NI
# 1                NI               NI          NI             NI
# 2                NI               NI          NI             NI
# 3                NI               NI          NI             NI
# 4                NI               NI          NI             NI
# 5                NI               NI          NI             NI
# 6                NI               NI          NI             NI
# 7                NI               NI          NI             NI
# 8                NI               NI          NI             NI
# 9                NI               NI          NI             NI
# 10               NI               NI          NI             NI
# 11               NI               NI          NI             NI
# 12               NI               NI          NI             NI
# 13               NI               NI          NI             NI
# 14               NI               NI          NI             NI
# 15               NI               NI          NI             NI
# 16               NI               NI          NI             NI
# 17               NI               NI          NI             NI
# 18               NI               NI          NI             NI
# 19               NI               NI          NI             NI
# 20               NI               NI          NI             NI
# 21               NI               NI          NI             NI
# 22               NI               NI          NI             NI
# 23               NI               NI          NI             NI
# 24               NI               NI          NI             NI
# 25               NI               NI          NI             NI
# 26               NI               NI          NI             NI
# 27               NI               NI          NI             NI
# 28               NI               NI          NI             NI
# 29               NI               NI          NI             NI
# ...             ...              ...         ...            ...
# 701711           NI               NI          NI             NI
# 701712           NI               NI          NI             NI
# 701713           NI               NI          NI             NI
# 701714           NI               NI          NI             NI
# 701715           NI               NI          NI             NI
# 701716           NI               NI          NI             NI
# 701717           NI               NI          NI             NI
# 701718           NI               NI          NI             NI
# 701719           NI               NI          NI             NI
# 701720           NI               NI          NI             NI
# 701721           NI               NI          NI             NI
# 701722           NI               NI          NI             NI
# 701723           NI               NI          NI             NI
# 701724           NI               NI          NI             NI
# 701725           NI               NI          NI             NI
# 701726           NI               NI          NI             NI
# 701727           NI               NI          NI             NI
# 701728           NI               NI          NI             NI
# 701729           NI               NI          NI             NI
# 701730           NI               NI          NI             NI
# 701731           NI               NI          NI             NI
# 701732           NI               NI          NI             NI
# 701733           NI               NI          NI             NI
# 701734           NI               NI          NI             NI
# 701735           NI               NI          NI             NI
# 701736           NI               NI          NI             NI
# 701737           NI               NI          NI             NI
# 701738           NI               NI          NI             NI
# 701739           NI               NI          NI             NI
# 701740           NI               NI          NI             NI
#
# [701741 rows x 56 columns]

# %% [markdown]
# Merge para geração da planilha sobre <b>'CURSO_GRAU'</b>

# %%
curse = pd.read_excel('DePara_Robo_Preços_Novo.xlsx', sheetname='Curso_Grau')
curse.head()
# Out:
# C:\Users\Lucas Barros\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
#                   CURSO_DE      GRAU_DE     CURSO_PARA    GRAU_PARA  \
# 0            ADMINISTRAÇÃO          NaN  ADMINISTRACAO  BACHARELADO
# 1    ADMINISTRAÇÃO (73488)  BACHARELADO  ADMINISTRACAO  BACHARELADO
# 2  ADMINISTRAÇÃO (1292296)  BACHARELADO  ADMINISTRACAO  BACHARELADO
# 3  ADMINISTRAÇÃO (1263584)  BACHARELADO  ADMINISTRACAO  BACHARELADO
# 4  ADMINISTRAÇÃO (1263711)  BACHARELADO  ADMINISTRACAO  BACHARELADO
#
#   ID_CURSO_PARA
# 0           001
# 1           001
# 2           001
# 3           001
# 4           001

# %%
curse['CURSO_DE'] = curse['CURSO_DE'].str.upper()
curse['GRAU_DE'] = curse['GRAU_DE'].str.upper()
curse['CURSO_PARA'] = curse['CURSO_PARA'].str.upper()
curse['GRAU_PARA'] = curse['GRAU_PARA'].str.upper()
curse['ID_CURSO_PARA'] = curse['ID_CURSO_PARA'].str.upper()

# %%
curse['chave_curso'] = curse['CURSO_DE'].fillna('')+curse['GRAU_DE'].fillna('')

# %%
#reordenar o dataframe
curse=curse[['CURSO_DE','GRAU_DE','chave_curso','CURSO_PARA','GRAU_PARA','ID_CURSO_PARA']]

# %%
rft.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#       ...     PRECO_DF PRECO_DESCONTO_DF QTD_CREDITOS_DF  chave_pgto  \
# 0     ...       461.11            461.11            None  CLARETIANO
# 1     ...       461.11            461.11            None  CLARETIANO
# 2     ...       461.11            461.11            None  CLARETIANO
# 3     ...       461.11            461.11            None  CLARETIANO
# 4     ...       461.11            461.11            None  CLARETIANO
#
#   PARA_Plano_Pagto                                          chave_cuf  \
# 0               NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1               NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2               NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3               NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4               NI              CLARETIANOCLARETIANOSantos  SPSantos
#
#    CIDADE_PARA  NOME_LOCAL_PARA  GRUPO_PARA  MARCA_PARA
# 0           NI               NI          NI          NI
# 1           NI               NI          NI          NI
# 2           NI               NI          NI          NI
# 3           NI               NI          NI          NI
# 4           NI               NI          NI          NI
#
# [5 rows x 56 columns]

# %%
rft['chave_curso'] = rs['DS_COUSER_NAME'].fillna('')+rs['DS_COURSE_DEGREE'].fillna('')

# %%
rft=pd.merge(rft, curse[['chave_curso','CURSO_PARA','GRAU_PARA','ID_CURSO_PARA']], on='chave_curso', how='left')
rft.head()
# Out:
#          ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID DS_COUSER_NAME  \
# 0  19488453 2019-02-01   CLARETIANO          141    Gastronomia
# 1  19488454 2019-02-01   CLARETIANO          141    Gastronomia
# 2  19488455 2019-02-01   CLARETIANO          141    Gastronomia
# 3  19488456 2019-02-01   CLARETIANO          141    Gastronomia
# 4  19488457 2019-02-01   CLARETIANO          141    Gastronomia
#
#   DS_COURSE_MODALITY DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0                EAD        Tecnólogo          BA            BA       None
# 1                EAD        Tecnólogo          RS            RS       None
# 2                EAD        Tecnólogo          PA            PA       None
# 3                EAD        Tecnólogo          SP            SP       None
# 4                EAD        Tecnólogo          SP            SP       None
#
#        ...       PARA_Plano_Pagto  \
# 0      ...                     NI
# 1      ...                     NI
# 2      ...                     NI
# 3      ...                     NI
# 4      ...                     NI
#
#                                            chave_cuf CIDADE_PARA  \
# 0          CLARETIANOCLARETIANOSalvador  BASalvador           NI
# 1  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...          NI
# 2          CLARETIANOCLARETIANOSantarem  PASantarem           NI
# 3    CLARETIANOCLARETIANOSanto André  SPSanto André           NI
# 4              CLARETIANOCLARETIANOSantos  SPSantos           NI
#
#   NOME_LOCAL_PARA GRUPO_PARA MARCA_PARA           chave_curso  CURSO_PARA  \
# 0              NI         NI         NI  GastronomiaTecnólogo         NaN
# 1              NI         NI         NI  GastronomiaTecnólogo         NaN
# 2              NI         NI         NI  GastronomiaTecnólogo         NaN
# 3              NI         NI         NI  GastronomiaTecnólogo         NaN
# 4              NI         NI         NI  GastronomiaTecnólogo         NaN
#
#    GRAU_PARA  ID_CURSO_PARA
# 0        NaN            NaN
# 1        NaN            NaN
# 2        NaN            NaN
# 3        NaN            NaN
# 4        NaN            NaN
#
# [5 rows x 60 columns]

# %%
rft["CURSO_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"CURSO_PARA": "CURSO_PARA_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 900688  19943850 2019-02-04       UNIBTA         None
# 900689  19943851 2019-02-04       UNIBTA         None
# 900690  19943852 2019-02-04       UNIBTA         None
# 900691  19943853 2019-02-04       UNIBTA         None
# 900692  19943854 2019-02-04       UNIBTA         None
# 900693  19943855 2019-02-04       UNIBTA         None
# 900694  19943856 2019-02-04       UNIBTA         None
# 900695  19943857 2019-02-04       UNIBTA         None
# 900696  19943858 2019-02-04       UNIBTA         None
# 900697  19943859 2019-02-04       UNIBTA         None
# 900698  19943860 2019-02-04       UNIBTA         None
# 900699  19943861 2019-02-04       UNIBTA         None
# 900700  19943862 2019-02-04       UNIBTA         None
# 900701  19943863 2019-02-04       UNIBTA         None
# 900702  19943864 2019-02-04       UNIBTA         None
# 900703  19943865 2019-02-04       UNIBTA         None
# 900704  19943866 2019-02-04       UNIBTA         None
# 900705  19943867 2019-02-04       UNIBTA         None
# 900706  19943868 2019-02-04       UNIBTA         None
# 900707  19943869 2019-02-04       UNIBTA         None
# 900708  19943870 2019-02-04       UNIBTA         None
# 900709  19943871 2019-02-04       UNIBTA         None
# 900710  19943872 2019-02-04       UNIBTA         None
# 900711  19943873 2019-02-04       UNIBTA         None
# 900712  19943874 2019-02-04       UNIBTA         None
# 900713  19943875 2019-02-04       UNIBTA         None
# 900714  19943876 2019-02-04       UNIBTA         None
# 900715  19943877 2019-02-04       UNIBTA         None
# 900716  19943878 2019-02-04       UNIBTA         None
# 900717  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 900688           Tecnólogo em Marketing Digital                EAD
# 900689           Tecnólogo em Segurança Pública                EAD
# 900690      Tecnólogo em Sistemas para Internet                EAD
# 900691                            Administração                EAD
# 900692                       Ciências Contábeis                EAD
# 900693                          Educação Física                EAD
# 900694              Letras - Português e Inglês                EAD
# 900695                                Pedagogia                EAD
# 900696            Tecnólogo em Gestão Comercial                EAD
# 900697  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900698           Tecnólogo em Gestão Financeira                EAD
# 900699              Tecnólogo em Gestão Pública                EAD
# 900700           Tecnólogo em Marketing Digital                EAD
# 900701           Tecnólogo em Segurança Pública                EAD
# 900702      Tecnólogo em Sistemas para Internet                EAD
# 900703                            Administração                EAD
# 900704                       Ciências Contábeis                EAD
# 900705                          Educação Física                EAD
# 900706              Letras - Português e Inglês                EAD
# 900707                                Pedagogia                EAD
# 900708            Tecnólogo em Gestão Comercial                EAD
# 900709  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900710           Tecnólogo em Gestão Financeira                EAD
# 900711              Tecnólogo em Gestão Pública                EAD
# 900712           Tecnólogo em Marketing Digital                EAD
# 900713           Tecnólogo em Segurança Pública                EAD
# 900714      Tecnólogo em Sistemas para Internet                EAD
# 900715                            Administração                EAD
# 900716                       Ciências Contábeis                EAD
# 900717                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID      ...        \
# 0             Tecnólogo          BA            BA       None      ...
# 1             Tecnólogo          RS            RS       None      ...
# 2             Tecnólogo          PA            PA       None      ...
# 3             Tecnólogo          SP            SP       None      ...
# 4             Tecnólogo          SP            SP       None      ...
# 5             Tecnólogo          SP            SP       None      ...
# 6             Tecnólogo          RO            RO       None      ...
# 7             Tecnólogo          SP            SP       None      ...
# 8             Tecnólogo          SP            SP       None      ...
# 9             Tecnólogo          MA            MA       None      ...
# 10            Tecnólogo          RO            RO       None      ...
# 11            Tecnólogo          SP            SP       None      ...
# 12            Tecnólogo          SP            SP       None      ...
# 13            Tecnólogo          SP            SP       None      ...
# 14            Tecnólogo          PE            PE       None      ...
# 15            Tecnólogo          MT            MT       None      ...
# 16            Tecnólogo          CE            CE       None      ...
# 17            Tecnólogo          SP            SP       None      ...
# 18            Tecnólogo          AM            AM       None      ...
# 19            Tecnólogo          DF            DF       None      ...
# 20            Tecnólogo          DF            DF       None      ...
# 21            Tecnólogo          PI            PI       None      ...
# 22            Tecnólogo          MG            MG       None      ...
# 23            Tecnólogo          MG            MG       None      ...
# 24            Tecnólogo          RO            RO       None      ...
# 25            Tecnólogo          ES            ES       None      ...
# 26            Tecnólogo          BA            BA       None      ...
# 27            Tecnólogo          RJ            RJ       None      ...
# 28            Tecnólogo          GO            GO       None      ...
# 29            Tecnólogo          SE            SE       None      ...
# ...                 ...         ...           ...        ...      ...
# 900688             None        None            CE       None      ...
# 900689             None        None            CE       None      ...
# 900690             None        None            CE       None      ...
# 900691             None        None            CE       None      ...
# 900692             None        None            CE       None      ...
# 900693             None        None            CE       None      ...
# 900694             None        None            CE       None      ...
# 900695             None        None            CE       None      ...
# 900696             None        None            CE       None      ...
# 900697             None        None            CE       None      ...
# 900698             None        None            CE       None      ...
# 900699             None        None            CE       None      ...
# 900700             None        None            CE       None      ...
# 900701             None        None            CE       None      ...
# 900702             None        None            CE       None      ...
# 900703             None        None            CE       None      ...
# 900704             None        None            CE       None      ...
# 900705             None        None            CE       None      ...
# 900706             None        None            CE       None      ...
# 900707             None        None            CE       None      ...
# 900708             None        None            CE       None      ...
# 900709             None        None            CE       None      ...
# 900710             None        None            CE       None      ...
# 900711             None        None            CE       None      ...
# 900712             None        None            CE       None      ...
# 900713             None        None            CE       None      ...
# 900714             None        None            CE       None      ...
# 900715             None        None            CE       None      ...
# 900716             None        None            CE       None      ...
# 900717             None        None            CE       None      ...
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 900688               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900689               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900690               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900691               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900692               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900693               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900694               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900695               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900696               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900697               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900698               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900699               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900700               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900701               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900702               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900703               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900704               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900705               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900706               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900707               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900708               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900709               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900710               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900711               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900712               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900713               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900714               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900715               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 900716               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 900717               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#        CIDADE_PARA NOME_LOCAL_PARA GRUPO_PARA MARCA_PARA  \
# 0               NI              NI         NI         NI
# 1               NI              NI         NI         NI
# 2               NI              NI         NI         NI
# 3               NI              NI         NI         NI
# 4               NI              NI         NI         NI
# 5               NI              NI         NI         NI
# 6               NI              NI         NI         NI
# 7               NI              NI         NI         NI
# 8               NI              NI         NI         NI
# 9               NI              NI         NI         NI
# 10              NI              NI         NI         NI
# 11              NI              NI         NI         NI
# 12              NI              NI         NI         NI
# 13              NI              NI         NI         NI
# 14              NI              NI         NI         NI
# 15              NI              NI         NI         NI
# 16              NI              NI         NI         NI
# 17              NI              NI         NI         NI
# 18              NI              NI         NI         NI
# 19              NI              NI         NI         NI
# 20              NI              NI         NI         NI
# 21              NI              NI         NI         NI
# 22              NI              NI         NI         NI
# 23              NI              NI         NI         NI
# 24              NI              NI         NI         NI
# 25              NI              NI         NI         NI
# 26              NI              NI         NI         NI
# 27              NI              NI         NI         NI
# 28              NI              NI         NI         NI
# 29              NI              NI         NI         NI
# ...            ...             ...        ...        ...
# 900688          NI              NI         NI         NI
# 900689          NI              NI         NI         NI
# 900690          NI              NI         NI         NI
# 900691          NI              NI         NI         NI
# 900692          NI              NI         NI         NI
# 900693          NI              NI         NI         NI
# 900694          NI              NI         NI         NI
# 900695          NI              NI         NI         NI
# 900696          NI              NI         NI         NI
# 900697          NI              NI         NI         NI
# 900698          NI              NI         NI         NI
# 900699          NI              NI         NI         NI
# 900700          NI              NI         NI         NI
# 900701          NI              NI         NI         NI
# 900702          NI              NI         NI         NI
# 900703          NI              NI         NI         NI
# 900704          NI              NI         NI         NI
# 900705          NI              NI         NI         NI
# 900706          NI              NI         NI         NI
# 900707          NI              NI         NI         NI
# 900708          NI              NI         NI         NI
# 900709          NI              NI         NI         NI
# 900710          NI              NI         NI         NI
# 900711          NI              NI         NI         NI
# 900712          NI              NI         NI         NI
# 900713          NI              NI         NI         NI
# 900714          NI              NI         NI         NI
# 900715          NI              NI         NI         NI
# 900716          NI              NI         NI         NI
# 900717          NI              NI         NI         NI
#
#                        chave_curso  CURSO_PARA_DF  GRAU_PARA  ID_CURSO_PARA
# 0             GastronomiaTecnólogo             NI        NaN            NaN
# 1             GastronomiaTecnólogo             NI        NaN            NaN
# 2             GastronomiaTecnólogo             NI        NaN            NaN
# 3             GastronomiaTecnólogo             NI        NaN            NaN
# 4             GastronomiaTecnólogo             NI        NaN            NaN
# 5             GastronomiaTecnólogo             NI        NaN            NaN
# 6             GastronomiaTecnólogo             NI        NaN            NaN
# 7             GastronomiaTecnólogo             NI        NaN            NaN
# 8             GastronomiaTecnólogo             NI        NaN            NaN
# 9             GastronomiaTecnólogo             NI        NaN            NaN
# 10            GastronomiaTecnólogo             NI        NaN            NaN
# 11            GastronomiaTecnólogo             NI        NaN            NaN
# 12            GastronomiaTecnólogo             NI        NaN            NaN
# 13            GastronomiaTecnólogo             NI        NaN            NaN
# 14            GastronomiaTecnólogo             NI        NaN            NaN
# 15            GastronomiaTecnólogo             NI        NaN            NaN
# 16            GastronomiaTecnólogo             NI        NaN            NaN
# 17            GastronomiaTecnólogo             NI        NaN            NaN
# 18            GastronomiaTecnólogo             NI        NaN            NaN
# 19            GastronomiaTecnólogo             NI        NaN            NaN
# 20            GastronomiaTecnólogo             NI        NaN            NaN
# 21            GastronomiaTecnólogo             NI        NaN            NaN
# 22            GastronomiaTecnólogo             NI        NaN            NaN
# 23            GastronomiaTecnólogo             NI        NaN            NaN
# 24            GastronomiaTecnólogo             NI        NaN            NaN
# 25            GastronomiaTecnólogo             NI        NaN            NaN
# 26            GastronomiaTecnólogo             NI        NaN            NaN
# 27            GastronomiaTecnólogo             NI        NaN            NaN
# 28      Gestão Ambiental Tecnólogo             NI        NaN            NaN
# 29      Gestão Ambiental Tecnólogo             NI        NaN            NaN
# ...                            ...            ...        ...            ...
# 900688                         NaN             NI        NaN            NaN
# 900689                         NaN             NI        NaN            NaN
# 900690                         NaN             NI        NaN            NaN
# 900691                         NaN             NI        NaN            NaN
# 900692                         NaN             NI        NaN            NaN
# 900693                         NaN             NI        NaN            NaN
# 900694                         NaN             NI        NaN            NaN
# 900695                         NaN             NI        NaN            NaN
# 900696                         NaN             NI        NaN            NaN
# 900697                         NaN             NI        NaN            NaN
# 900698                         NaN             NI        NaN            NaN
# 900699                         NaN             NI        NaN            NaN
# 900700                         NaN             NI        NaN            NaN
# 900701                         NaN             NI        NaN            NaN
# 900702                         NaN             NI        NaN            NaN
# 900703                         NaN             NI        NaN            NaN
# 900704                         NaN             NI        NaN            NaN
# 900705                         NaN             NI        NaN            NaN
# 900706                         NaN             NI        NaN            NaN
# 900707                         NaN             NI        NaN            NaN
# 900708                         NaN             NI        NaN            NaN
# 900709                         NaN             NI        NaN            NaN
# 900710                         NaN             NI        NaN            NaN
# 900711                         NaN             NI        NaN            NaN
# 900712                         NaN             NI        NaN            NaN
# 900713                         NaN             NI        NaN            NaN
# 900714                         NaN             NI        NaN            NaN
# 900715                         NaN             NI        NaN            NaN
# 900716                         NaN             NI        NaN            NaN
# 900717                         NaN             NI        NaN            NaN
#
# [900718 rows x 60 columns]

# %%
rft["GRAU_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"GRAU_PARA": "GRAU_PARA_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 900688  19943850 2019-02-04       UNIBTA         None
# 900689  19943851 2019-02-04       UNIBTA         None
# 900690  19943852 2019-02-04       UNIBTA         None
# 900691  19943853 2019-02-04       UNIBTA         None
# 900692  19943854 2019-02-04       UNIBTA         None
# 900693  19943855 2019-02-04       UNIBTA         None
# 900694  19943856 2019-02-04       UNIBTA         None
# 900695  19943857 2019-02-04       UNIBTA         None
# 900696  19943858 2019-02-04       UNIBTA         None
# 900697  19943859 2019-02-04       UNIBTA         None
# 900698  19943860 2019-02-04       UNIBTA         None
# 900699  19943861 2019-02-04       UNIBTA         None
# 900700  19943862 2019-02-04       UNIBTA         None
# 900701  19943863 2019-02-04       UNIBTA         None
# 900702  19943864 2019-02-04       UNIBTA         None
# 900703  19943865 2019-02-04       UNIBTA         None
# 900704  19943866 2019-02-04       UNIBTA         None
# 900705  19943867 2019-02-04       UNIBTA         None
# 900706  19943868 2019-02-04       UNIBTA         None
# 900707  19943869 2019-02-04       UNIBTA         None
# 900708  19943870 2019-02-04       UNIBTA         None
# 900709  19943871 2019-02-04       UNIBTA         None
# 900710  19943872 2019-02-04       UNIBTA         None
# 900711  19943873 2019-02-04       UNIBTA         None
# 900712  19943874 2019-02-04       UNIBTA         None
# 900713  19943875 2019-02-04       UNIBTA         None
# 900714  19943876 2019-02-04       UNIBTA         None
# 900715  19943877 2019-02-04       UNIBTA         None
# 900716  19943878 2019-02-04       UNIBTA         None
# 900717  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 900688           Tecnólogo em Marketing Digital                EAD
# 900689           Tecnólogo em Segurança Pública                EAD
# 900690      Tecnólogo em Sistemas para Internet                EAD
# 900691                            Administração                EAD
# 900692                       Ciências Contábeis                EAD
# 900693                          Educação Física                EAD
# 900694              Letras - Português e Inglês                EAD
# 900695                                Pedagogia                EAD
# 900696            Tecnólogo em Gestão Comercial                EAD
# 900697  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900698           Tecnólogo em Gestão Financeira                EAD
# 900699              Tecnólogo em Gestão Pública                EAD
# 900700           Tecnólogo em Marketing Digital                EAD
# 900701           Tecnólogo em Segurança Pública                EAD
# 900702      Tecnólogo em Sistemas para Internet                EAD
# 900703                            Administração                EAD
# 900704                       Ciências Contábeis                EAD
# 900705                          Educação Física                EAD
# 900706              Letras - Português e Inglês                EAD
# 900707                                Pedagogia                EAD
# 900708            Tecnólogo em Gestão Comercial                EAD
# 900709  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900710           Tecnólogo em Gestão Financeira                EAD
# 900711              Tecnólogo em Gestão Pública                EAD
# 900712           Tecnólogo em Marketing Digital                EAD
# 900713           Tecnólogo em Segurança Pública                EAD
# 900714      Tecnólogo em Sistemas para Internet                EAD
# 900715                            Administração                EAD
# 900716                       Ciências Contábeis                EAD
# 900717                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID      ...        \
# 0             Tecnólogo          BA            BA       None      ...
# 1             Tecnólogo          RS            RS       None      ...
# 2             Tecnólogo          PA            PA       None      ...
# 3             Tecnólogo          SP            SP       None      ...
# 4             Tecnólogo          SP            SP       None      ...
# 5             Tecnólogo          SP            SP       None      ...
# 6             Tecnólogo          RO            RO       None      ...
# 7             Tecnólogo          SP            SP       None      ...
# 8             Tecnólogo          SP            SP       None      ...
# 9             Tecnólogo          MA            MA       None      ...
# 10            Tecnólogo          RO            RO       None      ...
# 11            Tecnólogo          SP            SP       None      ...
# 12            Tecnólogo          SP            SP       None      ...
# 13            Tecnólogo          SP            SP       None      ...
# 14            Tecnólogo          PE            PE       None      ...
# 15            Tecnólogo          MT            MT       None      ...
# 16            Tecnólogo          CE            CE       None      ...
# 17            Tecnólogo          SP            SP       None      ...
# 18            Tecnólogo          AM            AM       None      ...
# 19            Tecnólogo          DF            DF       None      ...
# 20            Tecnólogo          DF            DF       None      ...
# 21            Tecnólogo          PI            PI       None      ...
# 22            Tecnólogo          MG            MG       None      ...
# 23            Tecnólogo          MG            MG       None      ...
# 24            Tecnólogo          RO            RO       None      ...
# 25            Tecnólogo          ES            ES       None      ...
# 26            Tecnólogo          BA            BA       None      ...
# 27            Tecnólogo          RJ            RJ       None      ...
# 28            Tecnólogo          GO            GO       None      ...
# 29            Tecnólogo          SE            SE       None      ...
# ...                 ...         ...           ...        ...      ...
# 900688             None        None            CE       None      ...
# 900689             None        None            CE       None      ...
# 900690             None        None            CE       None      ...
# 900691             None        None            CE       None      ...
# 900692             None        None            CE       None      ...
# 900693             None        None            CE       None      ...
# 900694             None        None            CE       None      ...
# 900695             None        None            CE       None      ...
# 900696             None        None            CE       None      ...
# 900697             None        None            CE       None      ...
# 900698             None        None            CE       None      ...
# 900699             None        None            CE       None      ...
# 900700             None        None            CE       None      ...
# 900701             None        None            CE       None      ...
# 900702             None        None            CE       None      ...
# 900703             None        None            CE       None      ...
# 900704             None        None            CE       None      ...
# 900705             None        None            CE       None      ...
# 900706             None        None            CE       None      ...
# 900707             None        None            CE       None      ...
# 900708             None        None            CE       None      ...
# 900709             None        None            CE       None      ...
# 900710             None        None            CE       None      ...
# 900711             None        None            CE       None      ...
# 900712             None        None            CE       None      ...
# 900713             None        None            CE       None      ...
# 900714             None        None            CE       None      ...
# 900715             None        None            CE       None      ...
# 900716             None        None            CE       None      ...
# 900717             None        None            CE       None      ...
#
#        PARA_Plano_Pagto                                          chave_cuf  \
# 0                    NI          CLARETIANOCLARETIANOSalvador  BASalvador
# 1                    NI  CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...
# 2                    NI          CLARETIANOCLARETIANOSantarem  PASantarem
# 3                    NI    CLARETIANOCLARETIANOSanto André  SPSanto André
# 4                    NI              CLARETIANOCLARETIANOSantos  SPSantos
# 5                    NI      CLARETIANOCLARETIANOSão Carlos  SPSão Carlos
# 6                    NI  CLARETIANOCLARETIANOSão Francisco do Guaporé  ...
# 7                    NI  CLARETIANOCLARETIANOSão José do Rio Preto  SPS...
# 8                    NI  CLARETIANOCLARETIANOSão José dos Campos  SPSão...
# 9                    NI          CLARETIANOCLARETIANOSão Luís  MASão Luís
# 10                   NI  CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...
# 11                   NI  CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...
# 12                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 13                   NI        CLARETIANOCLARETIANOSão Paulo  SPSão Paulo
# 14                   NI  CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...
# 15                   NI                CLARETIANOCLARETIANOSinop  MTSinop
# 16                   NI              CLARETIANOCLARETIANOSobral  CESobral
# 17                   NI          CLARETIANOCLARETIANOSorocaba  SPSorocaba
# 18                   NI        CLARETIANOCLARETIANOTabatinga  AMTabatinga
# 19                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 20                   NI      CLARETIANOCLARETIANOTaguatinga  DFTaguatinga
# 21                   NI          CLARETIANOCLARETIANOTeresina  PITeresina
# 22                   NI            CLARETIANOCLARETIANOUberaba  MGUberaba
# 23                   NI      CLARETIANOCLARETIANOUberlândia  MGUberlândia
# 24                   NI            CLARETIANOCLARETIANOVilhena  ROVilhena
# 25                   NI            CLARETIANOCLARETIANOVitória  ESVitória
# 26                   NI  CLARETIANOCLARETIANOVitória da Conquista  BAVi...
# 27                   NI  CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...
# 28                   NI          CLARETIANOCLARETIANOAnápolis  GOAnápolis
# 29                   NI            CLARETIANOCLARETIANOAracaju  SEAracaju
# ...                 ...                                                ...
# 900688               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900689               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900690               NI  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...
# 900691               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900692               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900693               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900694               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900695               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900696               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900697               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900698               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900699               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900700               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900701               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900702               NI       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba
# 900703               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900704               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900705               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900706               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900707               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900708               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900709               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900710               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900711               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900712               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900713               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900714               NI         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro
# 900715               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 900716               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
# 900717               NI           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro
#
#        CIDADE_PARA NOME_LOCAL_PARA GRUPO_PARA MARCA_PARA  \
# 0               NI              NI         NI         NI
# 1               NI              NI         NI         NI
# 2               NI              NI         NI         NI
# 3               NI              NI         NI         NI
# 4               NI              NI         NI         NI
# 5               NI              NI         NI         NI
# 6               NI              NI         NI         NI
# 7               NI              NI         NI         NI
# 8               NI              NI         NI         NI
# 9               NI              NI         NI         NI
# 10              NI              NI         NI         NI
# 11              NI              NI         NI         NI
# 12              NI              NI         NI         NI
# 13              NI              NI         NI         NI
# 14              NI              NI         NI         NI
# 15              NI              NI         NI         NI
# 16              NI              NI         NI         NI
# 17              NI              NI         NI         NI
# 18              NI              NI         NI         NI
# 19              NI              NI         NI         NI
# 20              NI              NI         NI         NI
# 21              NI              NI         NI         NI
# 22              NI              NI         NI         NI
# 23              NI              NI         NI         NI
# 24              NI              NI         NI         NI
# 25              NI              NI         NI         NI
# 26              NI              NI         NI         NI
# 27              NI              NI         NI         NI
# 28              NI              NI         NI         NI
# 29              NI              NI         NI         NI
# ...            ...             ...        ...        ...
# 900688          NI              NI         NI         NI
# 900689          NI              NI         NI         NI
# 900690          NI              NI         NI         NI
# 900691          NI              NI         NI         NI
# 900692          NI              NI         NI         NI
# 900693          NI              NI         NI         NI
# 900694          NI              NI         NI         NI
# 900695          NI              NI         NI         NI
# 900696          NI              NI         NI         NI
# 900697          NI              NI         NI         NI
# 900698          NI              NI         NI         NI
# 900699          NI              NI         NI         NI
# 900700          NI              NI         NI         NI
# 900701          NI              NI         NI         NI
# 900702          NI              NI         NI         NI
# 900703          NI              NI         NI         NI
# 900704          NI              NI         NI         NI
# 900705          NI              NI         NI         NI
# 900706          NI              NI         NI         NI
# 900707          NI              NI         NI         NI
# 900708          NI              NI         NI         NI
# 900709          NI              NI         NI         NI
# 900710          NI              NI         NI         NI
# 900711          NI              NI         NI         NI
# 900712          NI              NI         NI         NI
# 900713          NI              NI         NI         NI
# 900714          NI              NI         NI         NI
# 900715          NI              NI         NI         NI
# 900716          NI              NI         NI         NI
# 900717          NI              NI         NI         NI
#
#                        chave_curso  CURSO_PARA  GRAU_PARA_DF  ID_CURSO_PARA
# 0             GastronomiaTecnólogo          NI            NI            NaN
# 1             GastronomiaTecnólogo          NI            NI            NaN
# 2             GastronomiaTecnólogo          NI            NI            NaN
# 3             GastronomiaTecnólogo          NI            NI            NaN
# 4             GastronomiaTecnólogo          NI            NI            NaN
# 5             GastronomiaTecnólogo          NI            NI            NaN
# 6             GastronomiaTecnólogo          NI            NI            NaN
# 7             GastronomiaTecnólogo          NI            NI            NaN
# 8             GastronomiaTecnólogo          NI            NI            NaN
# 9             GastronomiaTecnólogo          NI            NI            NaN
# 10            GastronomiaTecnólogo          NI            NI            NaN
# 11            GastronomiaTecnólogo          NI            NI            NaN
# 12            GastronomiaTecnólogo          NI            NI            NaN
# 13            GastronomiaTecnólogo          NI            NI            NaN
# 14            GastronomiaTecnólogo          NI            NI            NaN
# 15            GastronomiaTecnólogo          NI            NI            NaN
# 16            GastronomiaTecnólogo          NI            NI            NaN
# 17            GastronomiaTecnólogo          NI            NI            NaN
# 18            GastronomiaTecnólogo          NI            NI            NaN
# 19            GastronomiaTecnólogo          NI            NI            NaN
# 20            GastronomiaTecnólogo          NI            NI            NaN
# 21            GastronomiaTecnólogo          NI            NI            NaN
# 22            GastronomiaTecnólogo          NI            NI            NaN
# 23            GastronomiaTecnólogo          NI            NI            NaN
# 24            GastronomiaTecnólogo          NI            NI            NaN
# 25            GastronomiaTecnólogo          NI            NI            NaN
# 26            GastronomiaTecnólogo          NI            NI            NaN
# 27            GastronomiaTecnólogo          NI            NI            NaN
# 28      Gestão Ambiental Tecnólogo          NI            NI            NaN
# 29      Gestão Ambiental Tecnólogo          NI            NI            NaN
# ...                            ...         ...           ...            ...
# 900688                         NaN          NI            NI            NaN
# 900689                         NaN          NI            NI            NaN
# 900690                         NaN          NI            NI            NaN
# 900691                         NaN          NI            NI            NaN
# 900692                         NaN          NI            NI            NaN
# 900693                         NaN          NI            NI            NaN
# 900694                         NaN          NI            NI            NaN
# 900695                         NaN          NI            NI            NaN
# 900696                         NaN          NI            NI            NaN
# 900697                         NaN          NI            NI            NaN
# 900698                         NaN          NI            NI            NaN
# 900699                         NaN          NI            NI            NaN
# 900700                         NaN          NI            NI            NaN
# 900701                         NaN          NI            NI            NaN
# 900702                         NaN          NI            NI            NaN
# 900703                         NaN          NI            NI            NaN
# 900704                         NaN          NI            NI            NaN
# 900705                         NaN          NI            NI            NaN
# 900706                         NaN          NI            NI            NaN
# 900707                         NaN          NI            NI            NaN
# 900708                         NaN          NI            NI            NaN
# 900709                         NaN          NI            NI            NaN
# 900710                         NaN          NI            NI            NaN
# 900711                         NaN          NI            NI            NaN
# 900712                         NaN          NI            NI            NaN
# 900713                         NaN          NI            NI            NaN
# 900714                         NaN          NI            NI            NaN
# 900715                         NaN          NI            NI            NaN
# 900716                         NaN          NI            NI            NaN
# 900717                         NaN          NI            NI            NaN
#
# [900718 rows x 60 columns]

# %%
rft["ID_CURSO_PARA"].fillna("NI", inplace = True) 
rft.rename(index=str, columns={"ID_CURSO_PARA": "ID_CURSO_PARA_DF"})
# Out:
#               ID    DT_DATE DS_IES_SIGLE DS_COURSE_ID  \
# 0       19488453 2019-02-01   CLARETIANO          141
# 1       19488454 2019-02-01   CLARETIANO          141
# 2       19488455 2019-02-01   CLARETIANO          141
# 3       19488456 2019-02-01   CLARETIANO          141
# 4       19488457 2019-02-01   CLARETIANO          141
# 5       19488458 2019-02-01   CLARETIANO          141
# 6       19488459 2019-02-01   CLARETIANO          141
# 7       19488460 2019-02-01   CLARETIANO          141
# 8       19488461 2019-02-01   CLARETIANO          141
# 9       19488462 2019-02-01   CLARETIANO          141
# 10      19488463 2019-02-01   CLARETIANO          141
# 11      19488464 2019-02-01   CLARETIANO          141
# 12      19488465 2019-02-01   CLARETIANO          141
# 13      19488466 2019-02-01   CLARETIANO          141
# 14      19488467 2019-02-01   CLARETIANO          141
# 15      19488468 2019-02-01   CLARETIANO          141
# 16      19488469 2019-02-01   CLARETIANO          141
# 17      19488470 2019-02-01   CLARETIANO          141
# 18      19488471 2019-02-01   CLARETIANO          141
# 19      19488472 2019-02-01   CLARETIANO          141
# 20      19488473 2019-02-01   CLARETIANO          141
# 21      19488474 2019-02-01   CLARETIANO          141
# 22      19488475 2019-02-01   CLARETIANO          141
# 23      19488476 2019-02-01   CLARETIANO          141
# 24      19488477 2019-02-01   CLARETIANO          141
# 25      19488478 2019-02-01   CLARETIANO          141
# 26      19488479 2019-02-01   CLARETIANO          141
# 27      19488480 2019-02-01   CLARETIANO          141
# 28      19488481 2019-02-01   CLARETIANO           26
# 29      19488482 2019-02-01   CLARETIANO           26
# ...          ...        ...          ...          ...
# 900688  19943850 2019-02-04       UNIBTA         None
# 900689  19943851 2019-02-04       UNIBTA         None
# 900690  19943852 2019-02-04       UNIBTA         None
# 900691  19943853 2019-02-04       UNIBTA         None
# 900692  19943854 2019-02-04       UNIBTA         None
# 900693  19943855 2019-02-04       UNIBTA         None
# 900694  19943856 2019-02-04       UNIBTA         None
# 900695  19943857 2019-02-04       UNIBTA         None
# 900696  19943858 2019-02-04       UNIBTA         None
# 900697  19943859 2019-02-04       UNIBTA         None
# 900698  19943860 2019-02-04       UNIBTA         None
# 900699  19943861 2019-02-04       UNIBTA         None
# 900700  19943862 2019-02-04       UNIBTA         None
# 900701  19943863 2019-02-04       UNIBTA         None
# 900702  19943864 2019-02-04       UNIBTA         None
# 900703  19943865 2019-02-04       UNIBTA         None
# 900704  19943866 2019-02-04       UNIBTA         None
# 900705  19943867 2019-02-04       UNIBTA         None
# 900706  19943868 2019-02-04       UNIBTA         None
# 900707  19943869 2019-02-04       UNIBTA         None
# 900708  19943870 2019-02-04       UNIBTA         None
# 900709  19943871 2019-02-04       UNIBTA         None
# 900710  19943872 2019-02-04       UNIBTA         None
# 900711  19943873 2019-02-04       UNIBTA         None
# 900712  19943874 2019-02-04       UNIBTA         None
# 900713  19943875 2019-02-04       UNIBTA         None
# 900714  19943876 2019-02-04       UNIBTA         None
# 900715  19943877 2019-02-04       UNIBTA         None
# 900716  19943878 2019-02-04       UNIBTA         None
# 900717  19943879 2019-02-04       UNIBTA         None
#
#                                  DS_COUSER_NAME DS_COURSE_MODALITY  \
# 0                                   Gastronomia                EAD
# 1                                   Gastronomia                EAD
# 2                                   Gastronomia                EAD
# 3                                   Gastronomia                EAD
# 4                                   Gastronomia                EAD
# 5                                   Gastronomia                EAD
# 6                                   Gastronomia                EAD
# 7                                   Gastronomia                EAD
# 8                                   Gastronomia                EAD
# 9                                   Gastronomia                EAD
# 10                                  Gastronomia                EAD
# 11                                  Gastronomia                EAD
# 12                                  Gastronomia                EAD
# 13                                  Gastronomia         Presencial
# 14                                  Gastronomia                EAD
# 15                                  Gastronomia                EAD
# 16                                  Gastronomia                EAD
# 17                                  Gastronomia                EAD
# 18                                  Gastronomia                EAD
# 19                                  Gastronomia                EAD
# 20                                  Gastronomia         Presencial
# 21                                  Gastronomia                EAD
# 22                                  Gastronomia                EAD
# 23                                  Gastronomia                EAD
# 24                                  Gastronomia                EAD
# 25                                  Gastronomia                EAD
# 26                                  Gastronomia                EAD
# 27                                  Gastronomia                EAD
# 28                            Gestão Ambiental                 EAD
# 29                            Gestão Ambiental                 EAD
# ...                                         ...                ...
# 900688           Tecnólogo em Marketing Digital                EAD
# 900689           Tecnólogo em Segurança Pública                EAD
# 900690      Tecnólogo em Sistemas para Internet                EAD
# 900691                            Administração                EAD
# 900692                       Ciências Contábeis                EAD
# 900693                          Educação Física                EAD
# 900694              Letras - Português e Inglês                EAD
# 900695                                Pedagogia                EAD
# 900696            Tecnólogo em Gestão Comercial                EAD
# 900697  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900698           Tecnólogo em Gestão Financeira                EAD
# 900699              Tecnólogo em Gestão Pública                EAD
# 900700           Tecnólogo em Marketing Digital                EAD
# 900701           Tecnólogo em Segurança Pública                EAD
# 900702      Tecnólogo em Sistemas para Internet                EAD
# 900703                            Administração                EAD
# 900704                       Ciências Contábeis                EAD
# 900705                          Educação Física                EAD
# 900706              Letras - Português e Inglês                EAD
# 900707                                Pedagogia                EAD
# 900708            Tecnólogo em Gestão Comercial                EAD
# 900709  Tecnólogo em Gestão de Recursos Humanos                EAD
# 900710           Tecnólogo em Gestão Financeira                EAD
# 900711              Tecnólogo em Gestão Pública                EAD
# 900712           Tecnólogo em Marketing Digital                EAD
# 900713           Tecnólogo em Segurança Pública                EAD
# 900714      Tecnólogo em Sistemas para Internet                EAD
# 900715                            Administração                EAD
# 900716                       Ciências Contábeis                EAD
# 900717                          Educação Física                EAD
#
#        DS_COURSE_DEGREE DS_STATE_ID DS_STATE_NAME DS_CITY_ID  \
# 0             Tecnólogo          BA            BA       None
# 1             Tecnólogo          RS            RS       None
# 2             Tecnólogo          PA            PA       None
# 3             Tecnólogo          SP            SP       None
# 4             Tecnólogo          SP            SP       None
# 5             Tecnólogo          SP            SP       None
# 6             Tecnólogo          RO            RO       None
# 7             Tecnólogo          SP            SP       None
# 8             Tecnólogo          SP            SP       None
# 9             Tecnólogo          MA            MA       None
# 10            Tecnólogo          RO            RO       None
# 11            Tecnólogo          SP            SP       None
# 12            Tecnólogo          SP            SP       None
# 13            Tecnólogo          SP            SP       None
# 14            Tecnólogo          PE            PE       None
# 15            Tecnólogo          MT            MT       None
# 16            Tecnólogo          CE            CE       None
# 17            Tecnólogo          SP            SP       None
# 18            Tecnólogo          AM            AM       None
# 19            Tecnólogo          DF            DF       None
# 20            Tecnólogo          DF            DF       None
# 21            Tecnólogo          PI            PI       None
# 22            Tecnólogo          MG            MG       None
# 23            Tecnólogo          MG            MG       None
# 24            Tecnólogo          RO            RO       None
# 25            Tecnólogo          ES            ES       None
# 26            Tecnólogo          BA            BA       None
# 27            Tecnólogo          RJ            RJ       None
# 28            Tecnólogo          GO            GO       None
# 29            Tecnólogo          SE            SE       None
# ...                 ...         ...           ...        ...
# 900688             None        None            CE       None
# 900689             None        None            CE       None
# 900690             None        None            CE       None
# 900691             None        None            CE       None
# 900692             None        None            CE       None
# 900693             None        None            CE       None
# 900694             None        None            CE       None
# 900695             None        None            CE       None
# 900696             None        None            CE       None
# 900697             None        None            CE       None
# 900698             None        None            CE       None
# 900699             None        None            CE       None
# 900700             None        None            CE       None
# 900701             None        None            CE       None
# 900702             None        None            CE       None
# 900703             None        None            CE       None
# 900704             None        None            CE       None
# 900705             None        None            CE       None
# 900706             None        None            CE       None
# 900707             None        None            CE       None
# 900708             None        None            CE       None
# 900709             None        None            CE       None
# 900710             None        None            CE       None
# 900711             None        None            CE       None
# 900712             None        None            CE       None
# 900713             None        None            CE       None
# 900714             None        None            CE       None
# 900715             None        None            CE       None
# 900716             None        None            CE       None
# 900717             None        None            CE       None
#
#               ...        PARA_Plano_Pagto  \
# 0             ...                      NI
# 1             ...                      NI
# 2             ...                      NI
# 3             ...                      NI
# 4             ...                      NI
# 5             ...                      NI
# 6             ...                      NI
# 7             ...                      NI
# 8             ...                      NI
# 9             ...                      NI
# 10            ...                      NI
# 11            ...                      NI
# 12            ...                      NI
# 13            ...                      NI
# 14            ...                      NI
# 15            ...                      NI
# 16            ...                      NI
# 17            ...                      NI
# 18            ...                      NI
# 19            ...                      NI
# 20            ...                      NI
# 21            ...                      NI
# 22            ...                      NI
# 23            ...                      NI
# 24            ...                      NI
# 25            ...                      NI
# 26            ...                      NI
# 27            ...                      NI
# 28            ...                      NI
# 29            ...                      NI
# ...           ...                     ...
# 900688        ...                      NI
# 900689        ...                      NI
# 900690        ...                      NI
# 900691        ...                      NI
# 900692        ...                      NI
# 900693        ...                      NI
# 900694        ...                      NI
# 900695        ...                      NI
# 900696        ...                      NI
# 900697        ...                      NI
# 900698        ...                      NI
# 900699        ...                      NI
# 900700        ...                      NI
# 900701        ...                      NI
# 900702        ...                      NI
# 900703        ...                      NI
# 900704        ...                      NI
# 900705        ...                      NI
# 900706        ...                      NI
# 900707        ...                      NI
# 900708        ...                      NI
# 900709        ...                      NI
# 900710        ...                      NI
# 900711        ...                      NI
# 900712        ...                      NI
# 900713        ...                      NI
# 900714        ...                      NI
# 900715        ...                      NI
# 900716        ...                      NI
# 900717        ...                      NI
#
#                                                 chave_cuf CIDADE_PARA  \
# 0               CLARETIANOCLARETIANOSalvador  BASalvador           NI
# 1       CLARETIANOCLARETIANOSanta Cruz do Sul  RSSanta...          NI
# 2               CLARETIANOCLARETIANOSantarem  PASantarem           NI
# 3         CLARETIANOCLARETIANOSanto André  SPSanto André           NI
# 4                   CLARETIANOCLARETIANOSantos  SPSantos           NI
# 5           CLARETIANOCLARETIANOSão Carlos  SPSão Carlos           NI
# 6       CLARETIANOCLARETIANOSão Francisco do Guaporé  ...          NI
# 7       CLARETIANOCLARETIANOSão José do Rio Preto  SPS...          NI
# 8       CLARETIANOCLARETIANOSão José dos Campos  SPSão...          NI
# 9               CLARETIANOCLARETIANOSão Luís  MASão Luís           NI
# 10      CLARETIANOCLARETIANOSão Miguel do Guaporé  ROS...          NI
# 11      CLARETIANOCLARETIANOSão Miguel Paulista  SPSão...          NI
# 12            CLARETIANOCLARETIANOSão Paulo  SPSão Paulo           NI
# 13            CLARETIANOCLARETIANOSão Paulo  SPSão Paulo           NI
# 14      CLARETIANOCLARETIANOSerra Talhada  PESerra Tal...          NI
# 15                    CLARETIANOCLARETIANOSinop  MTSinop           NI
# 16                  CLARETIANOCLARETIANOSobral  CESobral           NI
# 17              CLARETIANOCLARETIANOSorocaba  SPSorocaba           NI
# 18            CLARETIANOCLARETIANOTabatinga  AMTabatinga           NI
# 19          CLARETIANOCLARETIANOTaguatinga  DFTaguatinga           NI
# 20          CLARETIANOCLARETIANOTaguatinga  DFTaguatinga           NI
# 21              CLARETIANOCLARETIANOTeresina  PITeresina           NI
# 22                CLARETIANOCLARETIANOUberaba  MGUberaba           NI
# 23          CLARETIANOCLARETIANOUberlândia  MGUberlândia           NI
# 24                CLARETIANOCLARETIANOVilhena  ROVilhena           NI
# 25                CLARETIANOCLARETIANOVitória  ESVitória           NI
# 26      CLARETIANOCLARETIANOVitória da Conquista  BAVi...          NI
# 27      CLARETIANOCLARETIANOVolta Redonda  RJVolta Red...          NI
# 28              CLARETIANOCLARETIANOAnápolis  GOAnápolis           NI
# 29                CLARETIANOCLARETIANOAracaju  SEAracaju           NI
# ...                                                   ...         ...
# 900688  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...          NI
# 900689  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...          NI
# 900690  UNIBTAUNIBTASalvadorCEPolo Feira de Santana - ...          NI
# 900691       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900692       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900693       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900694       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900695       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900696       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900697       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900698       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900699       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900700       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900701       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900702       UNIBTAUNIBTASalvadorCEPolo Salvador - Pituba          NI
# 900703         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900704         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900705         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900706         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900707         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900708         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900709         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900710         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900711         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900712         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900713         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900714         UNIBTAUNIBTAUbatãCEPolo Barreiras - Centro          NI
# 900715           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro          NI
# 900716           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro          NI
# 900717           UNIBTAUNIBTAUbatãCEPolo Caetité - Centro          NI
#
#        NOME_LOCAL_PARA GRUPO_PARA MARCA_PARA                 chave_curso  \
# 0                   NI         NI         NI        GastronomiaTecnólogo
# 1                   NI         NI         NI        GastronomiaTecnólogo
# 2                   NI         NI         NI        GastronomiaTecnólogo
# 3                   NI         NI         NI        GastronomiaTecnólogo
# 4                   NI         NI         NI        GastronomiaTecnólogo
# 5                   NI         NI         NI        GastronomiaTecnólogo
# 6                   NI         NI         NI        GastronomiaTecnólogo
# 7                   NI         NI         NI        GastronomiaTecnólogo
# 8                   NI         NI         NI        GastronomiaTecnólogo
# 9                   NI         NI         NI        GastronomiaTecnólogo
# 10                  NI         NI         NI        GastronomiaTecnólogo
# 11                  NI         NI         NI        GastronomiaTecnólogo
# 12                  NI         NI         NI        GastronomiaTecnólogo
# 13                  NI         NI         NI        GastronomiaTecnólogo
# 14                  NI         NI         NI        GastronomiaTecnólogo
# 15                  NI         NI         NI        GastronomiaTecnólogo
# 16                  NI         NI         NI        GastronomiaTecnólogo
# 17                  NI         NI         NI        GastronomiaTecnólogo
# 18                  NI         NI         NI        GastronomiaTecnólogo
# 19                  NI         NI         NI        GastronomiaTecnólogo
# 20                  NI         NI         NI        GastronomiaTecnólogo
# 21                  NI         NI         NI        GastronomiaTecnólogo
# 22                  NI         NI         NI        GastronomiaTecnólogo
# 23                  NI         NI         NI        GastronomiaTecnólogo
# 24                  NI         NI         NI        GastronomiaTecnólogo
# 25                  NI         NI         NI        GastronomiaTecnólogo
# 26                  NI         NI         NI        GastronomiaTecnólogo
# 27                  NI         NI         NI        GastronomiaTecnólogo
# 28                  NI         NI         NI  Gestão Ambiental Tecnólogo
# 29                  NI         NI         NI  Gestão Ambiental Tecnólogo
# ...                ...        ...        ...                         ...
# 900688              NI         NI         NI                         NaN
# 900689              NI         NI         NI                         NaN
# 900690              NI         NI         NI                         NaN
# 900691              NI         NI         NI                         NaN
# 900692              NI         NI         NI                         NaN
# 900693              NI         NI         NI                         NaN
# 900694              NI         NI         NI                         NaN
# 900695              NI         NI         NI                         NaN
# 900696              NI         NI         NI                         NaN
# 900697              NI         NI         NI                         NaN
# 900698              NI         NI         NI                         NaN
# 900699              NI         NI         NI                         NaN
# 900700              NI         NI         NI                         NaN
# 900701              NI         NI         NI                         NaN
# 900702              NI         NI         NI                         NaN
# 900703              NI         NI         NI                         NaN
# 900704              NI         NI         NI                         NaN
# 900705              NI         NI         NI                         NaN
# 900706              NI         NI         NI                         NaN
# 900707              NI         NI         NI                         NaN
# 900708              NI         NI         NI                         NaN
# 900709              NI         NI         NI                         NaN
# 900710              NI         NI         NI                         NaN
# 900711              NI         NI         NI                         NaN
# 900712              NI         NI         NI                         NaN
# 900713              NI         NI         NI                         NaN
# 900714              NI         NI         NI                         NaN
# 900715              NI         NI         NI                         NaN
# 900716              NI         NI         NI                         NaN
# 900717              NI         NI         NI                         NaN
#
#         CURSO_PARA  GRAU_PARA  ID_CURSO_PARA_DF
# 0               NI         NI                NI
# 1               NI         NI                NI
# 2               NI         NI                NI
# 3               NI         NI                NI
# 4               NI         NI                NI
# 5               NI         NI                NI
# 6               NI         NI                NI
# 7               NI         NI                NI
# 8               NI         NI                NI
# 9               NI         NI                NI
# 10              NI         NI                NI
# 11              NI         NI                NI
# 12              NI         NI                NI
# 13              NI         NI                NI
# 14              NI         NI                NI
# 15              NI         NI                NI
# 16              NI         NI                NI
# 17              NI         NI                NI
# 18              NI         NI                NI
# 19              NI         NI                NI
# 20              NI         NI                NI
# 21              NI         NI                NI
# 22              NI         NI                NI
# 23              NI         NI                NI
# 24              NI         NI                NI
# 25              NI         NI                NI
# 26              NI         NI                NI
# 27              NI         NI                NI
# 28              NI         NI                NI
# 29              NI         NI                NI
# ...            ...        ...               ...
# 900688          NI         NI                NI
# 900689          NI         NI                NI
# 900690          NI         NI                NI
# 900691          NI         NI                NI
# 900692          NI         NI                NI
# 900693          NI         NI                NI
# 900694          NI         NI                NI
# 900695          NI         NI                NI
# 900696          NI         NI                NI
# 900697          NI         NI                NI
# 900698          NI         NI                NI
# 900699          NI         NI                NI
# 900700          NI         NI                NI
# 900701          NI         NI                NI
# 900702          NI         NI                NI
# 900703          NI         NI                NI
# 900704          NI         NI                NI
# 900705          NI         NI                NI
# 900706          NI         NI                NI
# 900707          NI         NI                NI
# 900708          NI         NI                NI
# 900709          NI         NI                NI
# 900710          NI         NI                NI
# 900711          NI         NI                NI
# 900712          NI         NI                NI
# 900713          NI         NI                NI
# 900714          NI         NI                NI
# 900715          NI         NI                NI
# 900716          NI         NI                NI
# 900717          NI         NI                NI
#
# [900718 rows x 60 columns]

# %% [markdown]
# <b>conexão postgreSQL</b><p>
# Host: pricing.cfefnwtyvvt2.us-east-1.rds.amazonaws.com<p>
# Port: 5432<p>
# Database: pricing<p>
# User: kroton_pricing<p>
# Pass: krt8s0F4<p>
# Schema: kroton_pricing

# %%
#Conexão ao Redshift - postgres
import pandas_redshift as pr
def to_redshift():
    pr.connect_to_redshift(dbname = 'pricing',
                        host  = 'pricing.cfefnwtyvvt2.us-east-1.rds.amazonaws.com',
                        port  = '5432',
                        user  = 'kroton_pricing',
                        password = 'krt8s0F4')
    print('Connect to RedShift')
    return pr.redshift_to_pandas('select * from kroton_pricing.bd_ccr')
#data = pr.redshift_to_pandas('select * from db_ccr')

# %%
df_conn = to_redshift()
# Out:
# Connect to RedShift

# %%
df_conn.head()
# Out:
#    id zona_influencia     cidade_uf grupo marca modalidade  \
# 0   1    SAO PAULO/SP  SAO PAULO/SP   FAJ   FAJ        EAD
# 1   2    SAO PAULO/SP  SAO PAULO/SP   FAJ   FAJ        EAD
# 2   3     BRASILIA/DF   BRASILIA/DF  IESB  IESB        EAD
# 3   4     BRASILIA/DF   BRASILIA/DF  IESB  IESB        EAD
# 4   5     BRASILIA/DF   BRASILIA/DF  IESB  IESB        EAD
#
#                      curso        turno         grau  unidade     ...      \
# 0  ARQUITETURA E URBANISMO  100% ONLINE  BACHARELADO  DEFAULT     ...
# 1                 FARMACIA  100% ONLINE  BACHARELADO  DEFAULT     ...
# 2              BIOMEDICINA  100% ONLINE  BACHARELADO  DEFAULT     ...
# 3         ENGENHARIA CIVIL  100% ONLINE  BACHARELADO  DEFAULT     ...
# 4   ENGENHARIA DE PRODUCAO  100% ONLINE  BACHARELADO  DEFAULT     ...
#
#   ult_vs_1a  perc_ult_vs_1a  ult_vs_penult  perc_ult_vs_penult  \
# 0       NaN           0.000            NaN               0.000
# 1       NaN           0.000            NaN               0.000
# 2      10.0          -0.135           10.0              -0.135
# 3      10.0          -0.153           10.0              -0.153
# 4       NaN           0.000            NaN                 NaN
#
#    primeira_medicao  penultima  ultima  origem data_penultima data_ultima
# 0             675.0      675.0   675.0    None           None        None
# 1             675.0      675.0   675.0    None           None        None
# 2             681.3      681.3   589.0    None           None        None
# 3             695.3      695.3   589.0    None           None        None
# 4             589.0        NaN   589.0    None           None        None
#
# [5 rows x 21 columns]

# %%
def to_redshift(data_frame):
    #date_str =data_base.strftime('%Y/%m/%d')
    print('connect_to_redshift')
    pr.connect_to_redshift(dbname = 'pricing',
                        host  = 'pricing.cfefnwtyvvt2.us-east-1.rds.amazonaws.com',
                        port  = '5432',
                        user  = 'kroton_pricing',
                        password = 'krt8s0F4')
    print('connect_to_s3')
    pr.connect_to_s3(aws_access_key_id="AKIAILQVO2DJQHRLFLQQ",
                     aws_secret_access_key="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",
                     bucket="kroton-analytics",
                     subdirectory="raw/uploads/esteira"
                     )
    print('pandas_to_redshift')
    pr.pandas_to_redshift(data_frame=data_frame,
                          ##columns_data_types = ['real_mes' float64, 'real_ano_anterior' float64, 'acumulado_ano' float64, 'meta_ano' float64],
                          ##column_data_types=['VARCHAR(250)','DATE','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','VARCHAR(250)','FLOAT','FLOAT','FLOAT','FLOAT'],
                          index=False,
                          ##column_data_types = None,
                          redshift_table_name='kroton_pricing.tb_dev_bd_ccr',
                          append = True)
    return print('fim save_to_redshift')

# %%
#export do dataframe para Redshift
to_redshift(rft)
